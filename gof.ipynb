# %% [markdown]
# # Goodness-of-fit test with Combine
# Assuming background model is rejected events (fail VAE cut) miltiplied by some transfer factor (single number or function of dijet invariant mass)

# %%
# Imports
import os, sys
import numpy as np
import ROOT as rt
import uproot
import h5py
import matplotlib.pyplot as plt
import root_numpy as rtnp
import pandas

from math import log10, floor
from subprocess import Popen
import shlex
# Out:
# Welcome to JupyROOT 6.12/07

# %%
# Set some important variables

# Rescaling the inputs to lumi
qcd_xsec       = 8730000.0 # Crossection in fb             
qcd_gen_events = 134366091.0+199435365.0+90490645.0+134264102.0 #(all generated QCD)
sig_xsec       = 10. #In units of fb (== 0.01 pb) 
sig_gen_events = 972050.0 #(all generated signal)
lumi           = qcd_gen_events/qcd_xsec # assuming 64/fb since qcd_gen_events/8730000 ~ 64

scale_qcd = qcd_xsec*lumi/qcd_gen_events
scale_sig = 0.8*sig_xsec*lumi/sig_gen_events #20% already used for quantile regression, must be removed
print('Usign luminosity {}'.format(lumi))
print('Scale QCD with {}'.format(scale_qcd))
print('Scale signal with {}'.format(scale_sig))

# Set binning
useDijet = False
# Dijet variable-binwidth binning (depends on dijet resolution)
if useDijet:
    histfile = 'histograms_dijet.root'
    wsfile   = 'datacard_ws_dijet'   #only prefix
    bin_edges = np.array([1126,1181,1246,1313,1383,1455,1530,
                          1607,1687,1770,1856,1945,2037,2132,
                          2231,2332,2438,2546,2659,2775,2895,
                          3019,3147,3279,3416,3558,3704,3854,
                          4010,4171,4337,4509,4686,4869,5058,
                          5253,5500,5663,5877,6099,6328,6564,6808]).astype('float')
    #Use reduced range
    bin_edges = np.array([1246,1313,1383,1455,1530,
                          1607,1687,1770,1856,1945,2037,2132,
                          2231,2332,2438,2546,2659,2775,2895,
                          3019,3147,3279,3416,3558,3704,3854,
                          4010,4171,4337,4509,4686,4869,5058]).astype('float')
#                         5253,5500,5663,5877,6099,6328,6564,6808]).astype('float')
# Constant binwidth
else:
    histfile = 'histograms_100GeV.root'
    wsfile   = 'datacard_ws_100GeV'   #only prefix
    bin_edges = np.array(np.arange(1200., 5000., 100.).tolist()).astype('float') #100 GeV binning
print(bin_edges)
n_bins = len(bin_edges)-1
max_bin = bin_edges[-1]
min_bin = bin_edges[0]

# Signal strengths to inject for statistical test
# Define some signal parameters
MX = 3500. #Signal mass in units of GeV
#sig_inj_vals = [0,0.1, 1, 2,5,10] #These correspond to xsecs of 0fb(used for GOF w.o signal), 1fb, 10fb, 20fb, 50fb, 100fb
sig_inj_vals = [0] #These correspond to xsecs of 0fb(used for GOF w.o signal), 1fb, 10fb, 20fb, 50fb, 100fb

# Where to save data histograms and workspace+datacards


#quantiles
quants = [0.01,0.1,0.3,0.5,0.7,0.9]

#Color style
scol = ['#fdd49e','#fdbb84','#fc8d59','#ef6548','#d7301f','#990000']
scol.reverse()
bcol = ['#ccece6','#99d8c9','#66c2a4','#41ae76','#238b45','#005824'] 
bcol.reverse()
# Out:
# Usign luminosity 63.981237457
# Scale QCD with 1.0
# Scale signal with 0.000526567460168
# [1200. 1300. 1400. 1500. 1600. 1700. 1800. 1900. 2000. 2100. 2200. 2300.
#  2400. 2500. 2600. 2700. 2800. 2900. 3000. 3100. 3200. 3300. 3400. 3500.
#  3600. 3700. 3800. 3900. 4000. 4100. 4200. 4300. 4400. 4500. 4600. 4700.
#  4800. 4900.]

# %%
#  Get the total, accepted and rejected events for signal and data
#path = '/eos/project/d/dshep/TOPCLASS/DijetAnomaly/VAE_results/run_111_210202/'
path = './'

f_qcd = h5py.File(path+'qcd_sqrtshatTeV_13TeV_PU40_reco.h5', 'r')
f_sig = h5py.File(path+'RSGraviton_WW_NARROW_13TeV_PU40_3.5TeV_reco.h5', 'r')

print(f_qcd.keys())
print(list(f_qcd.get("eventFeatureNames")))
print('N QCD events = {}'.format(len(f_qcd.get("eventFeatures"))))
# Out:
# [u'eventFeatureNames', u'eventFeatures']
# ['mJJ', 'j1Pt', 'j1Eta', 'j1Phi', 'j1M', 'j1E', 'j2Pt', 'j2M', 'j2E', 'DeltaEtaJJ', 'DeltaPhiJJ', 'j1TotalLoss', 'j1RecoLoss', 'j1KlLoss', 'j2TotalLoss', 'j2RecoLoss', 'j2KlLoss', 'sel_q90', 'sel_q70', 'sel_q50', 'sel_q30', 'sel_q10', 'sel_q01']
# N QCD events = 9588767

# %%
# Define which columns represent whiich variaibles

mjj_idx = int(np.where(f_qcd['eventFeatureNames'][()] == 'mJJ')[0])
deta_idx = int(np.where(f_sig['eventFeatureNames'][()] == 'DeltaEtaJJ')[0])

# Different quantiles (not yet orthogonal!)
columns   = {}
columns[0.9]  = int(np.where(f_qcd['eventFeatureNames'][()] == 'sel_q90')[0]) # 0=rejected 1=accepted
columns[0.7]  = int(np.where(f_qcd['eventFeatureNames'][()] == 'sel_q70')[0])
columns[0.5]  = int(np.where(f_qcd['eventFeatureNames'][()] == 'sel_q50')[0])
columns[0.3]  = int(np.where(f_qcd['eventFeatureNames'][()] == 'sel_q30')[0])
columns[0.1]  = int(np.where(f_qcd['eventFeatureNames'][()] == 'sel_q10')[0])
columns[0.01] = int(np.where(f_qcd['eventFeatureNames'][()] == 'sel_q01')[0])


# Get all features as numpy arrays and apply dEta cut
qcd_tot = np.array(f_qcd.get("eventFeatures"))
sig_tot = np.array(f_sig.get("eventFeatures"))
print('No dEta cut Total = {}'.format(sig_tot.shape[0]))
print('No dEta cut pass q 1% = {}'.format(sig_tot[sig_tot[:,columns[0.01]] == 1].shape[0]))
qcd_tot = qcd_tot[abs(qcd_tot[:,deta_idx]) < 1.40]
sig_tot = sig_tot[abs(sig_tot[:,deta_idx]) < 1.40]
print('With dEta cut Total = {}'.format(sig_tot.shape[0]))
print('With dEta cut pass q 1% = {}'.format(sig_tot[sig_tot[:,columns[0.01]] == 1].shape[0]))
# Out:
# No dEta cut Total = 605887
# No dEta cut pass q 1% = 31734
# With dEta cut Total = 531825
# With dEta cut pass q 1% = 31413

# %%
# Define the different dijet invariant mass datasets (total, orthogonal quantiles)
datas_qcd_acc = {}
datas_sig_acc = {}

sig_all      = sig_tot[:,mjj_idx]
qcd_all      = qcd_tot[:,mjj_idx]

#Define the main templates as the 'unused quantile' at 90-100% background efficiency
qcd_template = qcd_tot[qcd_tot[:,columns[0.9]] == 0]
qcd_template = qcd_template[:,mjj_idx]
sig_template = sig_tot[sig_tot[:,columns[0.9]] == 0]
sig_template = sig_template[:,mjj_idx]

# Make sure all quantiles are orthogonal (removing events passing q-1 from q distribution)
qcd = np.copy(qcd_tot)
sig = np.copy(sig_tot)

for key in sorted(columns.keys()):
    
    # Start with q=0.01 and take all events that pass cut on VAE
    datas_qcd_acc[key] = qcd[qcd[:,columns[key]] == 1]
    datas_qcd_acc[key] = datas_qcd_acc[key][:,mjj_idx]
    
    datas_sig_acc[key] = sig[sig[:,columns[key]] == 1]
    datas_sig_acc[key] = datas_sig_acc[key][:,mjj_idx]
    
    #Remove those events from dataset and continue to next quantile
    qcd = qcd[qcd[:,columns[key]] == 0]
    sig = sig[sig[:,columns[key]] == 0]

# %%
#Some quick control plots to check shapes
import cmsstyle #mplhep for Python2 cheatsheet
from matplotlib.lines import Line2D

fig, ax = plt.subplots()

for i,key in enumerate(sorted(datas_qcd_acc.keys())):
    if i > 0:
        lower_bound = sorted(datas_qcd_acc.keys())[i-1]
    else:
        lower_bound = 0.0 
    plt.hist(datas_qcd_acc[key],bins=bin_edges,label=r'Data (q = ${}-{}$)'.format(lower_bound,key),histtype='step', linewidth=2, facecolor='none', edgecolor=bcol[i],fill=True,density=True)
plt.hist(qcd_all,bins=bin_edges,label=r'Data all',histtype='step', linewidth=2,linestyle="dashed",  facecolor='none', edgecolor='Black',fill=True,density=True)
plt.hist(qcd_template,bins=bin_edges,label=r'Data rejected',histtype='step', linewidth=2, facecolor='none', edgecolor='Black',fill=True,density=True)
       
for i,key in enumerate(sorted(datas_sig_acc.keys())):
    if i > 0:
        lower_bound = sorted(datas_sig_acc.keys())[i-1]
    else:
        lower_bound = 0.0 
    plt.hist(datas_sig_acc[key],bins=bin_edges,label=r'G $\rightarrow$ WW (q = {}-{})'.format(lower_bound,key),histtype='step', linewidth=2, facecolor='none', edgecolor=scol[i],fill=True,density=True)
    
plt.hist(sig_all,bins=bin_edges,label=r'G $\rightarrow$ WW all',histtype='step', linewidth=2,linestyle="dashed",  facecolor='none', edgecolor='Black',fill=True,density=True)
plt.hist(sig_template,bins=bin_edges,label=r'G $\rightarrow$ WW rejected',histtype='step', linewidth=2, facecolor='none', edgecolor='Black',fill=True,density=True)
plt.hist(qcd_all,bins=bin_edges,histtype='step', linewidth=2,linestyle="dashed",  facecolor='none', edgecolor='Black',fill=True,density=True)
plt.hist(qcd_template,bins=bin_edges,histtype='step', linewidth=2, facecolor='none', edgecolor='Black',fill=True,density=True)
    
handles, labels = ax.get_legend_handles_labels()
new_handles = [Line2D([], [], c=h.get_edgecolor(),linestyle=h.get_linestyle()) for h in handles]
plt.ylabel('A.U')
plt.xlabel(u'$M_{jj}$ (GeV)')
plt.locator_params(nbins=4)
plt.legend(handles=new_handles, labels=labels,loc='best',frameon=False, ncol=2,fontsize='xx-small')
plt.savefig('signal_shapes_nolog.pdf')
# Out:
# /home/users/woodson/.local/lib/python2.7/site-packages/matplotlib/font_manager.py:1333: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /home/users/woodson/.local/lib/python2.7/site-packages/matplotlib/font_manager.py:1333: UserWarning: findfont: Font family [u'TeX Gyre Heros'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Sanity checks

#Check that sum of orthogonal quantiles yield total
print('N total data events = {}'.format(qcd_tot.shape[0]))
sum_quantiles = 0
for i,key in enumerate(sorted(datas_qcd_acc.keys())):
    sum_quantiles += datas_qcd_acc[key].shape[0]
print('Sum of all events up to 90th quantile = {}'.format(sum_quantiles))
print('Sum of all events between 90th-100th quantile = {}'.format(qcd_template.shape[0]))
print('N_total - N_1to90 - N_90to100 = {}'.format(qcd_tot.shape[0]-sum_quantiles-qcd_template.shape[0]))
# Out:
# N total data events = 9588761
# Sum of all events up to 90th quantile = 8628589
# Sum of all events between 90th-100th quantile = 960172
# N_total - N_1to90 - N_90to100 = 0

# %%
# Fill histograms using dijet binning and proper lumi scaling.
#These are the baseline histograms for statistical analysis.
axis_title = ['M_{jj}','Events']

#Fill and scale to lumi
background_hist_template = rt.TH1D('background_hist_template','background_hist_template',n_bins,bin_edges.astype('float'))
rtnp.fill_hist(background_hist_template, qcd_template, weights=None)
background_hist_template.Scale(scale_qcd)
background_hist_template.SetStats(0)
background_hist_template.Sumw2()

signal_hist_template     = rt.TH1D('signal_rej'    ,'signal_rej'    ,n_bins,bin_edges.astype('float'))
rtnp.fill_hist(signal_hist_template    , sig_template, weights=None)
signal_hist_template.Scale(scale_sig)
signal_hist_template.SetStats(0)
signal_hist_template.Sumw2()

background_hist_template.SetXTitle(axis_title[0])
background_hist_template.SetYTitle(axis_title[1])
background_hist_template.binning = bin_edges
background_hist_template.SetLineColor(rt.kBlack)
background_hist_template.SetLineColor(rt.kBlack)
background_hist_template.SetLineStyle(rt.kSolid)
background_hist_template.SetLineWidth(2)

leg = rt.TLegend(0.31, 0.6, 0.85, 0.9)
leg.SetNColumns(2)
leg.SetTextSize(0.035)
leg.SetBorderSize(0)
leg.SetFillStyle(0)

histos_data = {}
histos_signal = {}
scol = ['#fdd49e','#fdbb84','#fc8d59','#ef6548','#d7301f','#990000']
scol.reverse()
bcol = ['#ccece6','#99d8c9','#66c2a4','#41ae76','#238b45','#005824'] 
bcol.reverse()
colors = ['#d55e00','#cc79a7','#0072b2','#f0e442','#009e73','#b3de69','#fccde5','#d9d9d9']
i = 0
for keyD,keyS in zip( sorted(datas_qcd_acc.keys()), sorted(datas_sig_acc.keys()) ):
    histos_data[keyD]  = rt.TH1D('data_obs_{}'.format(keyD),'',n_bins,bin_edges.astype('float'))
    histos_signal[keyS]= rt.TH1D('signal_{}'  .format(keyS),'',n_bins,bin_edges.astype('float'))
    rtnp.fill_hist(histos_data[keyD]   , datas_qcd_acc[keyD], weights=None)
    rtnp.fill_hist(histos_signal[keyS] , datas_sig_acc[keyS], weights=None)
    
    histos_data[keyD].Scale(scale_qcd)
    histos_signal[keyS].Scale(scale_sig)
    
    histos_data[keyD]  .SetStats(0)
    histos_signal[keyS].SetStats(0)
    
    histos_data[keyD]  .Sumw2()
    histos_signal[keyS].Sumw2()

    histos_data[keyD].SetXTitle(axis_title[0])
    histos_data[keyD].SetYTitle(axis_title[1])
    histos_data[keyD].binning = bin_edges
    
    histos_signal[keyS].SetXTitle(axis_title[0])
    histos_signal[keyS].SetYTitle(axis_title[1])
    histos_signal[keyS].binning = bin_edges
    
    histos_data[keyD].SetLineColor(rt.TColor.GetColor(bcol[i]))
    histos_data[keyD].SetMarkerColor(rt.TColor.GetColor(bcol[i]))
    
    histos_signal[keyS].SetLineColor(rt.TColor.GetColor(scol[i]))
    histos_signal[keyS].SetLineStyle(rt.kSolid)
    histos_signal[keyS].SetLineWidth(2)
    histos_signal[keyS].SetFillColorAlpha((rt.TColor.GetColor(scol[i])), 0.30)

    histos_data[keyD].SetMarkerStyle(20+i)
    histos_data[keyD].SetMarkerSize(0.9)
    i += 1


#Draw
c = rt.TCanvas('c','c',800,800)
background_hist_template.Draw('HIST')
background_hist_template.SetTitle("")
background_hist_template.SetMinimum(0.1)
background_hist_template.SetMaximum(qcd_tot.shape[0])
signal_hist_template.SetLineColor(rt.kBlack)
signal_hist_template.SetLineStyle(rt.kSolid)
signal_hist_template.SetLineWidth(2)
signal_hist_template.Draw('HISTsame')
# signal_hist_template    .Draw('same HIST')

for i,key in enumerate(sorted(histos_data.keys())):
    if i > 0:
        lower_bound = sorted(histos_data.keys())[i-1]
    else:
        lower_bound = 0.0 
#     leg.AddEntry(histos_data[key], 'Data (q = {}-{})'.format(lower_bound,key), 'lep')
    leg.AddEntry(histos_data[key], 'Data    ', 'lep')
    leg.AddEntry(histos_signal[key], 'G#rightarrowWW   (q = {}-{})'.format(lower_bound,key), 'l')
    histos_data[key].Draw('pez same')
#     histos_signal[key].Scale(10000.)
    histos_signal[key].Draw('HIST same')   
leg.AddEntry(background_hist_template , 'QCD', 'l')   
leg.AddEntry(signal_hist_template , 'Signal (q = 0.9-1.0)', 'l') 
c.SetLogy()
c.SetTitle('')

leg.Draw("same")
c.Draw()
# Out:
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1D::Sumw2>: Sum of squares of weights structure already created

# %%
# Draw "nice" ratio plot for paper, check efficiency quantile/template and smoothness

c_out = rt.TCanvas("ratio", "", 1000, 800)
pad1 = rt.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0.001)
pad1.SetLeftMargin(0.13)
# pad1.SetGridx()
pad1.Draw()
pad1.cd()
leg = rt.TLegend(0.48, 0.5, 0.89, 0.85)
leg.SetNColumns(2)
leg.SetTextSize(0.05)
leg.SetBorderSize(0)
leg.SetFillStyle(0)

background_hist_template.Draw('HIST')
background_hist_template.SetTitle("")
background_hist_template.SetMinimum(0.2)
background_hist_template.SetMaximum(qcd_tot.shape[0]*1.2)
background_hist_template.GetYaxis().SetLabelSize(0.05)
background_hist_template.GetYaxis().SetTitleSize(0.05)
# signal_hist_template    .Draw('same HIST')
leg.SetTextSize (0.03)
leg.SetTextFont( 62 )
leg.SetHeader('Data:                        G #rightarrow WW (#sigma = 0.01 pb):')
leg.SetTextSize (0.03)
leg.SetTextFont( 42 )
for i,key in enumerate(sorted(histos_data.keys())):
    if i > 0:
        lower_bound = sorted(histos_data.keys())[i-1]
    else:
        lower_bound = 0.0 
    histos_data[key].Draw('pez same')
    histos_signal[key].Draw('HIST same')
    leg.AddEntry(histos_data[key]  , 'q = {} - {}'.format(lower_bound,key), 'lep')
    leg.AddEntry(histos_signal[key], 'q = {} - {}'.format(lower_bound,key), 'l')
background_hist_template.Draw('same HIST')
histos_signal[0.1].Draw('HIST same')
histos_signal[0.01].Draw('HIST same')
leg.SetTextSize(0.04)  
leg.AddEntry(background_hist_template , 'Bkg. template', 'l') 
leg.Draw('same')

pad1.SetLogy()
pad1.SetTitle('')

c_out.cd()
pad2 = rt.TPad("pad2", "pad2", 0, 0, 1, 0.3)
pad2.SetTopMargin(0.00)
pad2.SetBottomMargin(0.27)
pad2.SetLeftMargin(0.13)
# pad2.SetGrid()
pad2.Draw()
pad2.cd()
data_hist_ratio = {}
tline = {}
for i,key in enumerate(sorted(histos_data.keys())):
    pad2.cd()
    if i > 0:
        lower_bound = sorted(histos_data.keys())[i-1]
    else:
        lower_bound = 0.0 
    data_hist_ratio[key] = histos_data[key].Clone('data_hist_ratio_{}'.format(i))
    
    data_hist_ratio[key].Divide(background_hist_template)
    data_hist_ratio[key].binning = bin_edges
    # data_hist_ratio.Scale(data_hist_rej.Integral()/data_hist_acc.Integral())
    if i == 0:
        print(i)
        data_hist_ratio[key].SetTitle('')
        data_hist_ratio[key].Draw('pez')
        data_hist_ratio[key].SetMaximum(2.8)
        data_hist_ratio[key].SetMinimum(0.0)
        data_hist_ratio[key].SetYTitle('Data/Template')
        data_hist_ratio[key].GetYaxis().SetTitleOffset(0.5)
        data_hist_ratio[key].GetYaxis().SetTitleSize(0.12)
        data_hist_ratio[key].GetYaxis().SetLabelSize(0.12)
        data_hist_ratio[key].GetYaxis().SetNdivisions(506)
        data_hist_ratio[key].GetXaxis().SetNdivisions(506)
        data_hist_ratio[key].GetXaxis().SetTitleOffset(0.95)
        data_hist_ratio[key].GetXaxis().SetTitleSize(0.12)
        data_hist_ratio[key].GetXaxis().SetLabelSize(0.12)
        data_hist_ratio[key].GetXaxis().SetTickSize(0.07)
    else:
        data_hist_ratio[key].Draw('pez same')
    
    
    tline[key] = rt.TLine(min_bin, (key-lower_bound)/0.1, max_bin, (key-lower_bound)/0.1)
    tline[key].SetLineColor(rt.kBlack)
    tline[key].SetLineStyle(rt.kDashed)
    tline[key].Draw('same')

# sig_hist_ratio = signal_hist_acc.Clone('signal_hist_ratio')
# sig_hist_ratio.SetTitle('')
# sig_hist_ratio.Sumw2()
# sig_hist_ratio.Divide(signal_hist_rej)
# sig_hist_ratio.binning = bin_edges
# data_hist_ratio.Scale(data_hist_rej.Integral()/data_hist_acc.Integral())

# sig_hist_ratio.Draw('pez same')
c_out.cd()
latex = rt.TLatex()
latex.SetNDC ()
latex.SetTextSize (0.03)
latex.SetTextFont( 62 )
latex.DrawLatex (0.17 ,0.87 , "%.1f fb^{-1} dijet events"%lumi)
latex.SetTextSize (0.03)
latex.SetTextFont( 42 )
latex.DrawLatex(0.17 ,0.83 , "#Delta#eta_{jj} < 1.3, M_{jj} > 1246 GeV")
latex.DrawLatex(0.17 ,0.79 , "p_{T} > 200 GeV, |#eta| < 2.5")
c_out.Update()
c_out.Draw()
c_out.SaveAs('mjj_all.pdf')
# Out:
# 0
# Info in <TCanvas::Print>: pdf file mjj_all.pdf has been created

# %%
# define data for 90-100% quantile (used for control region datacards)
histos_data  [1.0] = background_hist_template
histos_signal[1.0] = signal_hist_template

# %%
# Make data with injected signal!
# Do some validation checks and plot data distribution with injected signal.
# Also make table with S/sqrt(B) over full dijet range and in mJJ window.

data = {'q':[],'q_string':[],'sig_inj':[],'mjjmin':[],  'mjjmax':[], 'NQCD':[], 'NSIG':[],'SB':[],'NQCD_SLICE':[], 'NSIG_SLICE':[],'SB_SLICE':[]}
        
# These dictionaries will contain the 90-100% quantile with injected signal (data_hist_rej_inj_all)
# and the orthogonal quantiles with injected signal (data_hist_acc_inj_all). They will be saved to 'histfile'
# The format is data_hist_rej_inj_all[quantile][sig_injected]

data_hist_rej_inj_all = {}
data_hist_acc_inj_all = {}

#Define signal Mjj window as 20% of each side of MX. Only used for drawing purposes and S/sqrt(B) values
axis = background_hist_template.GetXaxis()
bmin = axis.FindBin(MX*0.8)
bmax  = axis.FindBin(MX*1.2)
mjjmin = axis.GetBinCenter(bmin)
mjjmax = axis.GetBinCenter(bmax)

# Helper function to round numbers for TeX table
def round_sig(x, sig=1):
    if x == 0.:
        return 0
    else:
        return round(x, sig-int(floor(log10(abs(x))))-1)


leg = rt.TLegend(0.48, 0.5, 0.89, 0.85)
#stick to no injecion for now
c_out = rt.TCanvas("ratio", "", 1000, 800)
pad1 = rt.TPad("pad1", "pad1", 0, 0.3, 1, 1.0)
pad1.SetBottomMargin(0.001)
pad1.SetLeftMargin(0.13)
pad1.SetLogy()
pad1.SetTitle('')
pad1.Draw()
pad1.cd()
leg = rt.TLegend(0.45, 0.61, 0.89, 0.91)
leg.SetNColumns(2)
leg.SetTextSize(0.05)
leg.SetBorderSize(0)
leg.SetFillStyle(0)
leg.SetTextSize (0.03)
leg.SetTextFont( 62 )
leg.SetHeader('SR (#forall q):                  CR (q = 0.9 - 1.0):')
leg.SetTextSize (0.03)
leg.SetTextFont( 42 )
background_hist_template.Draw('HIST')
histos_signal[0.01].Draw('HISTsame')
background_hist_template.SetTitle("")
background_hist_template.SetMinimum(0.2)
background_hist_template.SetMaximum(qcd_tot.shape[0]*1.2)
background_hist_template.GetYaxis().SetLabelSize(0.05)
background_hist_template.GetYaxis().SetTitleSize(0.05)


for i,key in enumerate(sorted(histos_data.keys())):
    if i > 0:
        lower_bound = sorted(histos_data.keys())[i-1]
    else:
        lower_bound = 0.0 
#     if key == 1.0: #To skip reject quantile
#        continue
    prefix = 'q'+str(int(key*100))
#     print(prefix) 
#     print('Quantile integral = {}'.format(histos_data[key].Integral()))
#     print('Template integral = {} (10%efficiency)'.format(background_hist_template.Integral()))
#     print('Efficiency= {}'.format(histos_data[key].Integral()/background_hist_template.Integral()))
    
    data_hist_rej_inj = {}
    data_hist_acc_inj = {}
    for k,sig_inj in enumerate(sig_inj_vals):
        data_hist_rej_inj[sig_inj] = background_hist_template.Clone('background_hist_template_inj{}_{}'.format(sig_inj,prefix))
        data_hist_acc_inj[sig_inj] = histos_data[key].Clone('data_hist_acc_inj{}_{}'.format(sig_inj,prefix))
        data_hist_rej_inj[sig_inj].Add(signal_hist_template,sig_inj)
        data_hist_acc_inj[sig_inj].Add(histos_signal[key],sig_inj)
        
        # Compute some useful S/B quantities and print as latex table
        if sig_inj != 0:
            data['q'].append(key)
            keystring = '{} - {}'.format(lower_bound,key)
            data['q_string'].append(keystring)
            data['sig_inj'].append(int(sig_inj*10.))
            data['mjjmin'].append(mjjmin)
            data['mjjmax'].append(mjjmax)
            NQCD       = int(histos_data[key].Integral())
            NSIG       = int(data_hist_acc_inj[sig_inj].Integral())-int(histos_data[key].Integral())
            SB         = round_sig(NSIG/np.sqrt(NQCD))
            NQCD_SLICE = int(histos_data[key].Integral(bmin,bmax))
            NSIG_SLICE = int(data_hist_acc_inj[sig_inj].Integral(bmin,bmax))-int(histos_data[key].Integral(bmin,bmax))
            SB_SLICE   = round_sig(NSIG_SLICE/np.sqrt(NQCD_SLICE))
            data['NQCD'].append(NQCD)
            data['NSIG'].append(NSIG)
            data['SB'].append(SB)
            data['NQCD_SLICE'].append(NQCD_SLICE)
            data['NSIG_SLICE'].append(NSIG_SLICE)
            data['SB_SLICE'].append(SB_SLICE)
        if key != 1.0:
            data_hist_acc_inj[sig_inj].SetLineColor(rt.TColor.GetColor(bcol[i]))
            data_hist_acc_inj[sig_inj].SetLineStyle(k+1)
            data_hist_rej_inj[sig_inj].SetLineStyle(k+1)
            data_hist_acc_inj[sig_inj].SetLineWidth(2)
            data_hist_rej_inj[sig_inj].SetLineWidth(2)
            data_hist_rej_inj[sig_inj].Draw('sameHIST')
            data_hist_acc_inj[sig_inj].Draw('sameHIST')
        if key == 0.01:
            leg.AddEntry(data_hist_acc_inj[sig_inj],'Inj. #sigma = {} fb'.format(int(sig_inj*10.)),'l')
            leg.AddEntry(data_hist_rej_inj[sig_inj],'Inj. #sigma = {} fb'.format(int(sig_inj*10.)),'l')
            
        
    data_hist_rej_inj_all[key] = data_hist_rej_inj
    data_hist_acc_inj_all[key] = data_hist_acc_inj
    
dataP = pandas.DataFrame(data)
dataP.to_pickle('Yields.pkl')
print(dataP.to_latex(columns=['q_string','sig_inj','NQCD','NSIG','SB','NQCD_SLICE','NSIG_SLICE','SB_SLICE'],header=['q','$\sigma$ [fb]','$N_{bkg}$','$N_{sig}$','$S/\sqrt{B}$','$N_{bkg}$ ($M_{X} \pm 10\%$)','$N_{sig}$ ($M_{X} \pm 10\%$)','$S/\sqrt{B}$ ($M_{X} \pm 10\%$)'],index=False,escape=False)) 
leg2 = rt.TLegend(0.18, 0.12, 0.3, 0.2)
leg2.SetBorderSize(0)
leg2.SetFillStyle(0)
leg2.SetTextSize (0.04)
leg2.SetTextFont( 42 )
leg2.AddEntry(histos_signal[0.01],'G (M = 3.5 TeV) #rightarrow WW','l')
leg2.AddEntry(None,'(q = 0.01, #sigma = 10 fb)','')
leg2.Draw('same')
c_out.Update()


# Add ratio SRinj/CRinj
c_out.cd()
pad2 = rt.TPad("pad2", "pad2", 0, 0, 1, 0.3)
pad2.SetTopMargin(0.00)
pad2.SetBottomMargin(0.27)
pad2.SetLeftMargin(0.13)
# pad2.SetGrid()
pad2.Draw()
pad2.cd()
data_hist_ratio_all = {}
tline = {}
for i,key in enumerate(sorted(histos_data.keys())):
    if key == 1.0:
        continue
    data_hist_ratio = {}
    pad2.cd()
    if i > 0:
        lower_bound = sorted(histos_data.keys())[i-1]
    else:
        lower_bound = 0.0 
    
    for k,sig_inj in enumerate(sig_inj_vals):
        
        data_hist_ratio[sig_inj] = data_hist_acc_inj_all[key][sig_inj].Clone('data_hist_ratio_{}{}'.format(i,k))
        data_hist_ratio[sig_inj].Divide(data_hist_rej_inj_all[key][sig_inj])
        data_hist_ratio[sig_inj].binning = bin_edges

        if k == 0 and i == 0:
            data_hist_ratio[sig_inj].SetTitle('')
            data_hist_ratio[sig_inj].Draw('pez')
            data_hist_ratio[sig_inj].SetMaximum(2.8)
            data_hist_ratio[sig_inj].SetMinimum(0.0)
            data_hist_ratio[sig_inj].SetYTitle('#frac{Data+S_{in}}{Template+S_{in}}')
            data_hist_ratio[sig_inj].GetYaxis().SetTitleOffset(0.5)
            data_hist_ratio[sig_inj].GetYaxis().SetTitleSize(0.12)
            data_hist_ratio[sig_inj].GetYaxis().SetLabelSize(0.12)
            data_hist_ratio[sig_inj].GetYaxis().SetNdivisions(506)
            data_hist_ratio[sig_inj].GetXaxis().SetNdivisions(506)
            data_hist_ratio[sig_inj].GetXaxis().SetTitleOffset(0.95)
            data_hist_ratio[sig_inj].GetXaxis().SetTitleSize(0.12)
            data_hist_ratio[sig_inj].GetXaxis().SetLabelSize(0.12)
            data_hist_ratio[sig_inj].GetXaxis().SetTickSize(0.07)
        else:
            data_hist_ratio[sig_inj].Draw('pez same')
    
    data_hist_ratio_all[key] = data_hist_ratio
    
    tline[key] = rt.TLine(min_bin, (key-lower_bound)/0.1, max_bin, (key-lower_bound)/0.1)
    tline[key].SetLineColor(rt.kBlack)
    tline[key].SetLineStyle(rt.kDashed)
    tline[key].Draw('same')

vlineDown = rt.TLine(mjjmin, 0.0, mjjmin, 2.8)
vlineDown.SetLineColor(rt.TColor.GetColor(scol[0]))
vlineDown.SetLineStyle(rt.kDashed)
vlineDown.Draw('same')
vlineUp = rt.TLine(mjjmax, 0.0, mjjmax, 2.8)
vlineUp.SetLineColor(rt.TColor.GetColor(scol[0]))
vlineUp.SetLineStyle(rt.kDashed)
vlineUp.Draw('same')
c_out.cd()


latex = rt.TLatex()
latex.SetNDC ()
latex.SetTextSize (0.03)
latex.SetTextFont( 62 )
latex.DrawLatex (0.17 ,0.87 , "%.1f fb^{-1} dijet events"%lumi)
latex.SetTextSize (0.03)
latex.SetTextFont( 42 )
latex.DrawLatex(0.17 ,0.83 , "#Delta#eta_{jj} < 1.3, M_{jj} > 1246 GeV")
latex.DrawLatex(0.17 ,0.79 , "p_{T} > 200 GeV, |#eta| < 2.5")
c_out.Update()
c_out.Draw()
leg.Draw('same')
c_out.SaveAs('sigInj_all.pdf')


leg.Draw('same')
c_out.Draw()
# Out:
# \begin{tabular}{rrrrrrrr}
# \toprule
# Empty DataFrame
# Columns: Index([u'q_string', u'sig_inj', u'NQCD', u'NSIG', u'SB', u'NQCD_SLICE',
#        u'NSIG_SLICE', u'SB_SLICE'],
#       dtype='object')
# Index: RangeIndex(start=0, stop=0, step=1) \\
# \bottomrule
# \end{tabular}
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ratio
# Info in <TCanvas::Print>: pdf file sigInj_all.pdf has been created

# %%
# Make sure the data is correctly created and store all histograms to file (will be imported to workspace below)

outfile = rt.TFile(histfile, 'RECREATE' )

signal_hist_template.Write('signal_template')
background_hist_template.Write('background_template')
for i,qkey in enumerate(sorted(data_hist_acc_inj_all.keys())):
    quantile = int(qkey*100)
    histos_signal[qkey].Write('signal_q{}percent'.format(quantile))
    histos_data[qkey].Write('background_q{}percent'.format(quantile))
    for i,skey in enumerate(sorted(data_hist_acc_inj_all[key])):
        injected = int(skey*10.)
        prefix = 'inj{}fb_q{}percent'.format(injected,quantile)
        print('Quantile={} signalInj={}'.format(qkey,injected))
        print('{}: {} events'.format('data_acc_{}'.format(prefix),data_hist_acc_inj_all[qkey][skey].Integral()))
        data_hist_acc_inj_all[qkey][skey].Write('data_acc_{}'.format(prefix))
        data_hist_rej_inj_all[qkey][skey].Write('data_rej_{}'.format(prefix))


outfile.Close()
# Out:
# Quantile=0.01 signalInj=0
# data_acc_inj0fb_q1percent: 96660.0 events
# Quantile=0.1 signalInj=0
# data_acc_inj0fb_q10percent: 859768.0 events
# Quantile=0.3 signalInj=0
# data_acc_inj0fb_q30percent: 1920439.0 events
# Quantile=0.5 signalInj=0
# data_acc_inj0fb_q50percent: 1915840.0 events
# Quantile=0.7 signalInj=0
# data_acc_inj0fb_q70percent: 1915990.0 events
# Quantile=0.9 signalInj=0
# data_acc_inj0fb_q90percent: 1919562.0 events
# Quantile=1.0 signalInj=0
# data_acc_inj0fb_q100percent: 960139.0 events

# %%
# #Open histogram file and make workspace

# Which quantiles to look at
quants = [0.01]

for i,qkey in enumerate(quants):
    f = rt.TFile.Open(histfile,"r")
    #Which dataset (signal injected or not).  
    #for skey in sig_inj_valskeys.keys():
    skey = int(0) #Stick to no injected signal for now
    quantile = int(qkey*100)
    prefix = 'inj{}fb_q{}percent'.format(skey,quantile) #different name for all quantiles/injected signal
    
    # Get histograms
    background_hist_rej = f.Get('data_rej_{}'.format(prefix)); background_hist_rej.SetDirectory(0);
    background_hist_acc = f.Get('data_acc_{}'.format(prefix)); background_hist_acc.SetDirectory(0);
    signal_hist_acc     = f.Get('signal_q{}percent'.format(quantile)) ; signal_hist_acc.SetDirectory(0);
    signal_hist_rej     = f.Get('signal_template') ; signal_hist_rej.SetDirectory(0);
    f.Close() 
    print('Acc data {} events'.format(background_hist_acc.Integral()))
    print('Rej data {} events'.format(background_hist_rej.Integral()))
    print('Acc signal {} events'.format(signal_hist_acc.Integral()))
    print('Rej signal {} events'.format(signal_hist_rej.Integral()))
    
    #background_hist_acc.Scale(background_hist_rej.Integral()/background_hist_acc.Integral()) # Test if fit converges if normalizatins are same
    
    #TEST: set up SIMPLE worksapece for debugging (1-to-1 with Javiers code)
    efficiency = background_hist_acc.Integral()/background_hist_rej.Integral() #How much rej histogram needs to be scaled to match acc
    print('Using efficiency = {} '.format(efficiency))
    
    datacard_ws = rt.TFile.Open('{}_{}.root'.format(wsfile,prefix),'recreate')
    w = rt.RooWorkspace('w','w')
    x = rt.RooRealVar('x','x',min_bin,max_bin)
    w.factory('x[%.1f,%.1f]'%(min_bin, max_bin))

    acc_bin_functions = rt.RooArgList()
    rej_bin_functions = rt.RooArgList()
    w.factory('eff[%f,%f,%f]'%(efficiency,np.maximum(0.,efficiency*0.2),np.maximum(1.,efficiency*2)))
    w.var('eff').setConstant(False) #I'm letting this float for now

    empty_hist = rt.TH1D('empty_hist','empty_hist', n_bins, min_bin, max_bin)
    for iBinX in range(1,n_bins+1):
        print('Bin {}'.format(iBinX))
        print('Eff = {}'.format(efficiency))
        print('Background model = {}'.format(background_hist_rej.GetBinContent(iBinX)))
        print('Data             = {}'.format(background_hist_acc.GetBinContent(iBinX)))
        print('Prediction       = {}'.format(background_hist_rej.GetBinContent(iBinX)*efficiency))
        mjj = background_hist_rej.GetBinContent(iBinX)
        tsB = mjj*pow(1.0+1/np.sqrt(mjj),iBinX)
        print('Test statistics bkg.= {}'.format(tsB))
        mjj_data = background_hist_acc.GetBinContent(iBinX)
        tsD = mjj_data*pow(1.0+1/np.sqrt(mjj_data),iBinX)
        print('Test statistics data = {}'.format(tsD))
        print('Test statistics esti = {}'.format(tsB*efficiency))
#         print('Test statistics = {}'format(background_hist_rej.GetBinContent(iBinX)*pow(1.0+1/rt.TMath.Sqrt(background_hist_rej.GetBinContent(iBinX),iBinX))))
        empty_hist.SetBinContent(iBinX,1)
        w.factory('crBin%i_In[%.1f]'%(iBinX,background_hist_rej.GetBinContent(iBinX)))
        w.factory('crBin%i[0,-10,10]'%(iBinX))
        w.var('crBin%i_In'%iBinX).setConstant(True)
        w.var('crBin%i'%iBinX).setConstant(False)
        #Added this as zero bin content protection. Commenting it out for now and making sure only non-zero binis are present
        if background_hist_rej.GetBinContent(iBinX) !=  0.:
            power = 1/rt.TMath.Sqrt(background_hist_rej.GetBinContent(iBinX))
        else:
            power = 0.0
        #what is fit is actually (mjj+mjj/sqrt(mjj))^x_bin, meaning x_bin is representative of how many sigma acc is from rej
        w.factory("expr::crBin%iFunc('max(0,@0*pow(1.0+%f,@1))',crBin%i_In,crBin%i)"%(iBinX,power,iBinX,iBinX))
        w.factory("expr::bin%iFunc('max(0,@0*@1)',eff,crBin%iFunc)"%(iBinX,iBinX))
        rej_bin_functions.add(w.function('crBin%iFunc'%iBinX))
        acc_bin_functions.add(w.function('bin%iFunc'%iBinX))

    qcd_rph_rej = rt.RooParametricHist('background_rej','background_acc',w.var('x'),rej_bin_functions,empty_hist)
    qcd_rph_rej_norm = rt.RooAddition('background_rej_norm','background_rej_norm',rej_bin_functions)
    qcd_rph_acc = rt.RooParametricHist('background_acc','background_acc',w.var('x'),acc_bin_functions,empty_hist)
    qcd_rph_acc_norm = rt.RooAddition('background_acc_norm','background_acc_norm',acc_bin_functions)
    getattr(w,'import')(qcd_rph_rej, rt.RooCmdArg())
    getattr(w,'import')(qcd_rph_rej_norm, rt.RooFit.RecycleConflictNodes())
    getattr(w,'import')(qcd_rph_acc, rt.RooCmdArg())
    getattr(w,'import')(qcd_rph_acc_norm, rt.RooFit.RecycleConflictNodes())

    ds_signal_acc = rt.RooDataHist('signal_acc','signal_acc',rt.RooArgList(w.var('x')),signal_hist_acc)
    ds_signal_rej = rt.RooDataHist('signal_rej','signal_rej',rt.RooArgList(w.var('x')),signal_hist_rej)
    getattr(w,'import')(ds_signal_acc, rt.RooCmdArg())
    getattr(w,'import')(ds_signal_rej, rt.RooCmdArg())

    sig_inj = 0
    ds_data_acc = rt.RooDataHist('data_obs_acc','data_obs_acc',rt.RooArgList(w.var('x')),background_hist_acc)
    ds_data_rej = rt.RooDataHist('data_obs_rej','data_obs_rej',rt.RooArgList(w.var('x')),background_hist_rej)
    getattr(w,'import')(ds_data_acc, rt.RooCmdArg())
    getattr(w,'import')(ds_data_rej, rt.RooCmdArg())

    datacard_ws.cd()
    w.Write()
    datacard_ws.Close()
    w.var('eff').Print()
    del w
# Out:
# Acc data 96660.0 events
# Rej data 960139.0 events
# Acc signal 16.5121024159 events
# Rej signal 18.8274195383 events
# Using efficiency = 0.1006729234
# Bin 1
# Eff = 0.1006729234
# Background model = 338072.0
# Data             = 34070.0
# Prediction       = 34034.6965596
# Test statistics bkg.= 338653.439593
# Test statistics data = 34254.5806057
# Test statistics esti = 34093.2317831
# Bin 2
# Eff = 0.1006729234
# Background model = 208905.0
# Data             = 20966.0
# Prediction       = 21031.0770628
# Test statistics bkg.= 209820.12253
# Test statistics data = 21256.5928176
# Test statistics esti = 21123.2051232
# Bin 3
# Eff = 0.1006729234
# Background model = 133033.0
# Data             = 13217.0
# Prediction       = 13392.8210186
# Test statistics bkg.= 134130.213416
# Test statistics data = 13564.9043347
# Test statistics esti = 13503.2807008
# Bin 4
# Eff = 0.1006729234
# Background model = 86258.0
# Data             = 9106.0
# Prediction       = 8683.84502661
# Test statistics bkg.= 87438.8021227
# Test statistics data = 9493.74348141
# Test statistics esti = 8802.71982825
# Bin 5
# Eff = 0.1006729234
# Background model = 58089.0
# Data             = 5834.0
# Prediction       = 5847.98944736
# Test statistics bkg.= 59304.1245618
# Test statistics data = 6226.03491162
# Test statistics esti = 5970.31958929
# Bin 6
# Eff = 0.1006729234
# Background model = 39126.0
# Data             = 3791.0
# Prediction       = 3938.92880093
# Test statistics bkg.= 40327.9190883
# Test statistics data = 4175.75539294
# Test statistics esti = 4059.92950924
# Bin 7
# Eff = 0.1006729234
# Background model = 27029.0
# Data             = 2731.0
# Prediction       = 2721.08844657
# Test statistics bkg.= 28201.0491029
# Test statistics data = 3118.49549903
# Test statistics esti = 2839.08205612
# Bin 8
# Eff = 0.1006729234
# Background model = 18904.0
# Data             = 1868.0
# Prediction       = 1903.12094395
# Test statistics bkg.= 20032.345565
# Test statistics data = 2243.09678497
# Test statistics esti = 2016.71479058
# Bin 9
# Eff = 0.1006729234
# Background model = 13400.0
# Data             = 1347.0
# Prediction       = 1349.01717356
# Test statistics bkg.= 14478.5604554
# Test statistics data = 1715.69835909
# Test statistics esti = 1457.59900766
# Bin 10
# Eff = 0.1006729234
# Background model = 9742.0
# Data             = 953.0
# Prediction       = 980.755619759
# Test statistics bkg.= 10775.2533106
# Test statistics data = 1310.82332009
# Test statistics esti = 1084.77625115
# Bin 11
# Eff = 0.1006729234
# Background model = 6898.0
# Data             = 700.0
# Prediction       = 694.441825611
# Test statistics bkg.= 7868.63150156
# Test statistics data = 1052.76640105
# Test statistics esti = 792.158136417
# Bin 12
# Eff = 0.1006729234
# Background model = 5088.0
# Data             = 485.0
# Prediction       = 512.223834257
# Test statistics bkg.= 6013.14636896
# Test statistics data = 826.361126216
# Test statistics esti = 605.361023794
# Bin 13
# Eff = 0.1006729234
# Background model = 3716.0
# Data             = 412.0
# Prediction       = 374.100583353
# Test statistics bkg.= 4591.35693088
# Test statistics data = 769.861350483
# Test statistics esti = 462.225324603
# Bin 14
# Eff = 0.1006729234
# Background model = 2818.0
# Data             = 266.0
# Prediction       = 283.69629814
# Test statistics bkg.= 3659.41366304
# Test statistics data = 611.921569832
# Test statistics esti = 368.403871387
# Bin 15
# Eff = 0.1006729234
# Background model = 2026.0
# Data             = 196.0
# Prediction       = 203.963342808
# Test statistics bkg.= 2816.98318822
# Test statistics data = 551.701826823
# Test statistics esti = 283.593932725
# Bin 16
# Eff = 0.1006729234
# Background model = 1494.0
# Data             = 169.0
# Prediction       = 150.405347559
# Test statistics bkg.= 2248.2224534
# Test statistics data = 553.148372028
# Test statistics esti = 226.335126837
# Bin 17
# Eff = 0.1006729234
# Background model = 1159.0
# Data             = 109.0
# Prediction       = 116.67991822
# Test statistics bkg.= 1895.94359045
# Test statistics data = 516.109067818
# Test statistics esti = 190.870183852
# Bin 18
# Eff = 0.1006729234
# Background model = 973.0
# Data             = 89.0
# Prediction       = 97.9547544678
# Test statistics bkg.= 1717.08076922
# Test statistics data = 545.733725892
# Test statistics esti = 172.863540751
# Bin 19
# Eff = 0.1006729234
# Background model = 729.0
# Data             = 88.0
# Prediction       = 73.3905611583
# Test statistics bkg.= 1454.85129445
# Test statistics data = 602.987063204
# Test statistics esti = 146.464132924
# Bin 20
# Eff = 0.1006729234
# Background model = 585.0
# Data             = 48.0
# Prediction       = 58.8936601888
# Test statistics bkg.= 1315.36975121
# Test statistics data = 711.744875099
# Test statistics esti = 132.422118205
# Bin 21
# Eff = 0.1006729234
# Background model = 472.0
# Data             = 45.0
# Prediction       = 47.5176198446
# Test statistics bkg.= 1214.38914915
# Test statistics data = 832.718544835
# Test statistics esti = 122.25610579
# Bin 22
# Eff = 0.1006729234
# Background model = 337.0
# Data             = 26.0
# Prediction       = 33.9267751857
# Test statistics bkg.= 1082.46628271
# Test statistics data = 1336.5555801
# Test statistics esti = 108.975045162
# Bin 23
# Eff = 0.1006729234
# Background model = 274.0
# Data             = 28.0
# Prediction       = 27.5843810115
# Test statistics bkg.= 1056.01262467
# Test statistics data = 1500.34610643
# Test statistics esti = 106.311878072
# Bin 24
# Eff = 0.1006729234
# Background model = 190.0
# Data             = 29.0
# Prediction       = 19.1278554459
# Test statistics bkg.= 1020.35583848
# Test statistics data = 1728.83160837
# Test statistics esti = 102.722205167
# Bin 25
# Eff = 0.1006729234
# Background model = 206.0
# Data             = 20.0
# Prediction       = 20.7386222203
# Test statistics bkg.= 1109.54807407
# Test statistics data = 3105.11022786
# Test statistics esti = 111.701448269
# Bin 26
# Eff = 0.1006729234
# Background model = 114.0
# Data             = 15.0
# Prediction       = 11.4767132676
# Test statistics bkg.= 1169.04368116
# Test statistics data = 5882.64982762
# Test statistics esti = 117.691044964
# Bin 27
# Eff = 0.1006729234
# Background model = 111.0
# Data             = 10.0
# Prediction       = 11.1746944974
# Test statistics bkg.= 1284.11077626
# Test statistics data = 16670.1035589
# Test statistics esti = 129.275185815
# Bin 28
# Eff = 0.1006729234
# Background model = 86.0
# Data             = 6.0
# Prediction       = 8.65787141237
# Test statistics bkg.= 1512.78182404
# Test statistics data = 87331.2680035
# Test statistics esti = 152.296168692
# Bin 29
# Eff = 0.1006729234
# Background model = 64.0
# Data             = 7.0
# Prediction       = 6.44306709758
# Test statistics bkg.= 1948.0635705
# Test statistics data = 76383.6906583
# Test statistics esti = 196.11725461
# Bin 30
# Eff = 0.1006729234
# Background model = 60.0
# Data             = 5.0
# Prediction       = 6.04037540398
# Test statistics bkg.= 2291.48525375
# Test statistics data = 327302.269513
# Test statistics esti = 230.690519422
# Bin 31
# Eff = 0.1006729234
# Background model = 53.0
# Data             = 3.0
# Prediction       = 5.33566494018
# Test statistics bkg.= 2864.96293616
# Test statistics data = 4101037.36418
# Test statistics esti = 288.424194214
# Bin 32
# Eff = 0.1006729234
# Background model = 30.0
# Data             = 4.0
# Prediction       = 3.02018770199
# Test statistics bkg.= 6421.40235967
# Test statistics data = 1725759.5331
# Test statistics esti = 646.461347873
# Bin 33
# Eff = 0.1006729234
# Background model = 22.0
# Data             = 7.0
# Prediction       = 2.21480431479
# Test statistics bkg.= 12947.9316245
# Test statistics data = 275392.888389
# Test statistics esti = 1303.50612862
# Bin 34
# Eff = 0.1006729234
# Background model = 26.0
# Data             = 3.0
# Prediction       = 2.61749600839
# Test statistics bkg.= 11462.1796245
# Test statistics data = 16094524.8156
# Test statistics esti = 1153.93113133
# Bin 35
# Eff = 0.1006729234
# Background model = 19.0
# Data             = 5.0
# Prediction       = 1.91278554459
# Test statistics bkg.= 26194.5197689
# Test statistics data = 2077840.39678
# Test statistics esti = 2637.07888218
# Bin 36
# Eff = 0.1006729234
# Background model = 15.0
# Data             = 1.0
# Prediction       = 1.51009385099
# Test statistics bkg.= 58487.8926021
# Test statistics data = 68719476736.0
# Test statistics esti = 5888.14713174
# Bin 37
# Eff = 0.1006729234
# Background model = 16.0
# Data             = 1.0
# Prediction       = 1.61076677439
# Test statistics bkg.= 61629.7582204
# Test statistics data = 1.37438953472e+11
# Test statistics esti = 6204.44792846
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooParametricHist::background_rej
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin1Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin1_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin1 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin2Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin2_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin2 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin3Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin3_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin3 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin4Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin4_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin4 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin5Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin5_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin5 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin6Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin6_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin6 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin7Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin7_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin7 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin8Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin8_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin8 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin9Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin9_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin9 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin10Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin10_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin10 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin11Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin11_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin11 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin12Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin12_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin12 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin13Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin13_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin13 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin14Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin14_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin14 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin15Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin15_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin15 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin16Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin16_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin16 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin17Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin17_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin17 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin18Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin18_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin18 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin19Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin19_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin19 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin20Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin20_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin20 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin21Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin21_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin21 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin22Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin22_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin22 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin23Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin23_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin23 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin24Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin24_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin24 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin25Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin25_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin25 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin26Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin26_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin26 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin27Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin27_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin27 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin28Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin28_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin28 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin29Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin29_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin29 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin30Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin30_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin30 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin31Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin31_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin31 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin32Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin32_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin32 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin33Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin33_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin33 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin34Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin34_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin34 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin35Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin35_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin35 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin36Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin36_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin36 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin37Func for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin37_In for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin37 for import of RooAddition::background_rej_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooParametricHist::background_acc
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin1Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::eff for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin1Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin1_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin1 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin2Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin2Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin2_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin2 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin3Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin3Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin3_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin3 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin4Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin4Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin4_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin4 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin5Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin5Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin5_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin5 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin6Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin6Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin6_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin6 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin7Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin7Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin7_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin7 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin8Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin8Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin8_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin8 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin9Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin9Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin9_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin9 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin10Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin10Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin10_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin10 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin11Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin11Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin11_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin11 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin12Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin12Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin12_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin12 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin13Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin13Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin13_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin13 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin14Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin14Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin14_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin14 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin15Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin15Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin15_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin15 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin16Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin16Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin16_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin16 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin17Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin17Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin17_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin17 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin18Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin18Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin18_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin18 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin19Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin19Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin19_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin19 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin20Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin20Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin20_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin20 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin21Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin21Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin21_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin21 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin22Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin22Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin22_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin22 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin23Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin23Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin23_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin23 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin24Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin24Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin24_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin24 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin25Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin25Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin25_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin25 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin26Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin26Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin26_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin26 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin27Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin27Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin27_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin27 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin28Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin28Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin28_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin28 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin29Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin29Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin29_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin29 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin30Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin30Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin30_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin30 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin31Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin31Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin31_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin31 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin32Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin32Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin32_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin32 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin33Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin33Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin33_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin33 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin34Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin34Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin34_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin34 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin35Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin35Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin35_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin35 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin36Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin36Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin36_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin36 for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::bin37Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooFormulaVar::crBin37Func for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin37_In for import of RooAddition::background_acc_norm
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) using existing copy of RooRealVar::crBin37 for import of RooAddition::background_acc_norm
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(signal_acc): fit range of variable x expanded to nearest bin boundaries: [1200,4900] --> [1200,4900]
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(signal_rej): fit range of variable x expanded to nearest bin boundaries: [1200,4900] --> [1200,4900]
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset signal_acc
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset signal_rej
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(data_obs_acc): fit range of variable x expanded to nearest bin boundaries: [1200,4900] --> [1200,4900]
# [#1] INFO:DataHandling -- RooDataHist::adjustBinning(data_obs_rej): fit range of variable x expanded to nearest bin boundaries: [1200,4900] --> [1200,4900]
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset data_obs_acc
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing dataset data_obs_rej
# RooRealVar::eff = 0.100673  L(0.020135 - 1)

# %%
# datacard template
# no background normalization uncertainty
for i,qkey in enumerate(quants):
    f = rt.TFile.Open(histfile,"r")
    skey = int(0)
    quantile = int(qkey*100)
    prefix = 'inj{}fb_q{}percent'.format(skey,quantile)
    signal_hist_acc     = f.Get('signal_q{}percent'.format(quantile)); signal_hist_acc.SetDirectory(0);
    signal_hist_rej     = f.Get('signal_template')                   ; signal_hist_rej.SetDirectory(0);
    f.Close()
    wsname = '{}_{}.root'.format(wsfile,prefix)
    datacard_ratio = \
    '''
    imax 1
    jmax 1
    kmax *
    ---------------
    shapes * * {WS} w:$PROCESS_$CHANNEL w:$PROCESS_$CHANNEL_$SYSTEMATIC
    ---------------
    bin {BIN}
    observation {OBS}
    ------------------------------
    bin             {BIN}      {BIN}
    process         signal     background
    process         0          1
    rate            {SIGRATE}    {BKGRATE}
    --------------------------------
    lumi lnN 1.01 -
    eff   flatParam
    '''

    for i in range(1,n_bins+1):
        datacard_ratio += 'crBin%i   flatParam\n'%i

    # write datacard
    datacard_ratio_acc = datacard_ratio.format(WS=wsname,
                                               BIN='acc',
                                               OBS=-1,
                                               BKGRATE=1,
                                               SIGRATE=signal_hist_acc.Integral())
    print(datacard_ratio_acc)
    with open('{}_ratio_acc_{}.txt'.format(wsfile,prefix),'w') as f:
        f.write(datacard_ratio_acc)


    datacard_ratio_rej = datacard_ratio.format(WS=wsname,
                                               BIN='rej',
                                               OBS=-1,
                                               BKGRATE=1,
                                               SIGRATE=signal_hist_rej.Integral())
    print(datacard_ratio_rej)
    with open('{}_ratio_rej_{}.txt'.format(wsfile,prefix),'w') as f:
        f.write(datacard_ratio_rej)
# Out:
#     imax 1
#     jmax 1
#     kmax *
#     ---------------
#     shapes * * datacard_ws_100GeV_inj0fb_q1percent.root w:$PROCESS_$CHANNEL w:$PROCESS_$CHANNEL_$SYSTEMATIC
#     ---------------
#     bin acc
#     observation -1
#     ------------------------------
#     bin             acc      acc
#     process         signal     background
#     process         0          1
#     rate            16.5121024159    1
#     --------------------------------
#     lumi lnN 1.01 -
#     eff   flatParam
#     crBin1   flatParam
# crBin2   flatParam
# crBin3   flatParam
# crBin4   flatParam
# crBin5   flatParam
# crBin6   flatParam
# crBin7   flatParam
# crBin8   flatParam
# crBin9   flatParam
# crBin10   flatParam
# crBin11   flatParam
# crBin12   flatParam
# crBin13   flatParam
# crBin14   flatParam
# crBin15   flatParam
# crBin16   flatParam
# crBin17   flatParam
# crBin18   flatParam
# crBin19   flatParam
# crBin20   flatParam
# crBin21   flatParam
# crBin22   flatParam
# crBin23   flatParam
# crBin24   flatParam
# crBin25   flatParam
# crBin26   flatParam
# crBin27   flatParam
# crBin28   flatParam
# crBin29   flatParam
# crBin30   flatParam
# crBin31   flatParam
# crBin32   flatParam
# crBin33   flatParam
# crBin34   flatParam
# crBin35   flatParam
# crBin36   flatParam
# crBin37   flatParam
#
#
#     imax 1
#     jmax 1
#     kmax *
#     ---------------
#     shapes * * datacard_ws_100GeV_inj0fb_q1percent.root w:$PROCESS_$CHANNEL w:$PROCESS_$CHANNEL_$SYSTEMATIC
#     ---------------
#     bin rej
#     observation -1
#     ------------------------------
#     bin             rej      rej
#     process         signal     background
#     process         0          1
#     rate            18.8274195383    1
#     --------------------------------
#     lumi lnN 1.01 -
#     eff   flatParam
#     crBin1   flatParam
# crBin2   flatParam
# crBin3   flatParam
# crBin4   flatParam
# crBin5   flatParam
# crBin6   flatParam
# crBin7   flatParam
# crBin8   flatParam
# crBin9   flatParam
# crBin10   flatParam
# crBin11   flatParam
# crBin12   flatParam
# crBin13   flatParam
# crBin14   flatParam
# crBin15   flatParam
# crBin16   flatParam
# crBin17   flatParam
# crBin18   flatParam
# crBin19   flatParam
# crBin20   flatParam
# crBin21   flatParam
# crBin22   flatParam
# crBin23   flatParam
# crBin24   flatParam
# crBin25   flatParam
# crBin26   flatParam
# crBin27   flatParam
# crBin28   flatParam
# crBin29   flatParam
# crBin30   flatParam
# crBin31   flatParam
# crBin32   flatParam
# crBin33   flatParam
# crBin34   flatParam
# crBin35   flatParam
# crBin36   flatParam
# crBin37   flatParam

# %%
for i,qkey in enumerate(quants):
    skey = int(0)
    quantile = int(qkey*100)
    prefix = 'inj{}fb_q{}percent'.format(skey,quantile)
    get_ipython().system(u'combineCards.py rej={WNAME}_ratio_rej_{P}.txt acc={WNAME}_ratio_acc_{P}.txt > {WNAME}_ratio_{P}.txt'.format(P=prefix, WNAME=wsfile))

# %%
# Simple test and fit diagnostics
prefix = 'inj{}fb_q{}percent'.format(0,1)
get_ipython().system('combine -M FitDiagnostics -d {WNAME}_ratio_{P}.txt -n _fit_result --saveShapes --saveWithUncertainties --dataset data_obs --plots -v 2'.format(P=prefix, WNAME=wsfile))
get_ipython().system('combine -M GoodnessOfFit --algo saturated --fixedSignalStrength 0 -d {WNAME}_ratio_{P}.txt -n {WNAME}_Ratio_{P} --dataset data_obs -v 2'.format(P=prefix, WNAME=wsfile))
# Out:
# >>> method used is FitDiagnostics
# >>> random number generator seed is 123456
# COMBINE_OUTPUT_FILE: higgsCombine_fit_result.FitDiagnostics.mH120.root
# Creating pdfs for individual modes (2): .    .   done.
# Object crBin1Func is duplicated
# Object crBin2Func is duplicated
# Object crBin3Func is duplicated
# Object crBin4Func is duplicated
# Object crBin5Func is duplicated
# Object crBin6Func is duplicated
# Object crBin7Func is duplicated
# Object crBin8Func is duplicated
# Object crBin9Func is duplicated
# Object crBin10Func is duplicated
# Object crBin11Func is duplicated
# Object crBin12Func is duplicated
# Object crBin13Func is duplicated
# Object crBin14Func is duplicated
# Object crBin15Func is duplicated
# Object crBin16Func is duplicated
# Object crBin17Func is duplicated
# Object crBin18Func is duplicated
# Object crBin19Func is duplicated
# Object crBin20Func is duplicated
# Object crBin21Func is duplicated
# Object crBin22Func is duplicated
# Object crBin23Func is duplicated
# Object crBin24Func is duplicated
# Object crBin25Func is duplicated
# Object crBin26Func is duplicated
# Object crBin27Func is duplicated
# Object crBin28Func is duplicated
# Object crBin29Func is duplicated
# Object crBin30Func is duplicated
# Object crBin31Func is duplicated
# Object crBin32Func is duplicated
# Object crBin33Func is duplicated
# Object crBin34Func is duplicated
# Object crBin35Func is duplicated
# Object crBin36Func is duplicated
# Object crBin37Func is duplicated
# Object bin1Func is duplicated
# Object bin2Func is duplicated
# Object bin3Func is duplicated
# Object bin4Func is duplicated
# Object bin5Func is duplicated
# Object bin6Func is duplicated
# Object bin7Func is duplicated
# Object bin8Func is duplicated
# Object bin9Func is duplicated
# Object bin10Func is duplicated
# Object bin11Func is duplicated
# Object bin12Func is duplicated
# Object bin13Func is duplicated
# Object bin14Func is duplicated
# Object bin15Func is duplicated
# Object bin16Func is duplicated
# Object bin17Func is duplicated
# Object bin18Func is duplicated
# Object bin19Func is duplicated
# Object bin20Func is duplicated
# Object bin21Func is duplicated
# Object bin22Func is duplicated
# Object bin23Func is duplicated
# Object bin24Func is duplicated
# Object bin25Func is duplicated
# Object bin26Func is duplicated
# Object bin27Func is duplicated
# Object bin28Func is duplicated
# Object bin29Func is duplicated
# Object bin30Func is duplicated
# Object bin31Func is duplicated
# Object bin32Func is duplicated
# Object bin33Func is duplicated
# Object bin34Func is duplicated
# Object bin35Func is duplicated
# Object bin36Func is duplicated
# Object bin37Func is duplicated
# Importing combined pdf model_s
# Missing background ModelConfig 'ModelConfig_bonly' in workspace 'w' in file roostats-xigdYp.root
# Will make one from the signal ModelConfig 'ModelConfig' setting signal strenth 'r' to zero
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x5fa3a10
#   Clients:
#     (0x5fa6070,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x5e5e020,V-) RooAddPdf::pdf_binrej_nuis ""
#     (0x5fa49f0,V-) RooProdPdf::pdfbins_binrej ""
#     (0x5e80350,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         lumi_Pdf
#       2)  pdf_binrej_nuis
#       3)   pdfbins_binrej
# --- RooAbsReal ---
#
#   Plot label is "pdf_binrej"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore rej (rej)
#   Contains 37 entries
#   Observables:
#     1)       x = 4850  L(1200 - 4900) B(37)  "x"
#     2)  weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in rej_x, pdf pdf_binrej = 960158
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x5fb5b30
#   Clients:
#     (0x5fa6070,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x5fb6ae0,V-) RooAddPdf::pdf_binacc_nuis ""
#     (0x6027170,V-) RooProdPdf::pdfbins_binacc ""
#     (0x5e80350,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         lumi_Pdf
#       2)  pdf_binacc_nuis
#       3)   pdfbins_binacc
# --- RooAbsReal ---
#
#   Plot label is "pdf_binacc"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore acc (acc)
#   Contains 37 entries
#   Observables:
#     1)       x = 4850  L(1200 - 4900) B(37)  "x"
#     2)  weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in acc_x, pdf pdf_binacc = 96676.6
# Error in <TList::Clear>: A list is accessing an object (0x6072c0c) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6072eb4) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./rej_x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./rej_x_prefit_logy.png has been created
# Info in <TCanvas::Print>: png file ./acc_x_prefit.png has been created
# Info in <TCanvas::Print>: png file ./acc_x_prefit_logy.png has been created
#
#   RooFitResult: minimized FCN value: -3.2454, estimated distance to minimum: 9.63468e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#             crBin10_In    9.7420e+03
#             crBin11_In    6.8980e+03
#             crBin12_In    5.0880e+03
#             crBin13_In    3.7160e+03
#             crBin14_In    2.8180e+03
#             crBin15_In    2.0260e+03
#             crBin16_In    1.4940e+03
#             crBin17_In    1.1590e+03
#             crBin18_In    9.7300e+02
#             crBin19_In    7.2900e+02
#              crBin1_In    3.3807e+05
#             crBin20_In    5.8500e+02
#             crBin21_In    4.7200e+02
#             crBin22_In    3.3700e+02
#             crBin23_In    2.7400e+02
#             crBin24_In    1.9000e+02
#             crBin25_In    2.0600e+02
#             crBin26_In    1.1400e+02
#             crBin27_In    1.1100e+02
#             crBin28_In    8.6000e+01
#             crBin29_In    6.4000e+01
#              crBin2_In    2.0890e+05
#             crBin30_In    6.0000e+01
#             crBin31_In    5.3000e+01
#             crBin32_In    3.0000e+01
#             crBin33_In    2.2000e+01
#             crBin34_In    2.6000e+01
#             crBin35_In    1.9000e+01
#             crBin36_In    1.5000e+01
#             crBin37_In    1.6000e+01
#              crBin3_In    1.3303e+05
#              crBin4_In    8.6258e+04
#              crBin5_In    5.8089e+04
#              crBin6_In    3.9126e+04
#              crBin7_In    2.7029e+04
#              crBin8_In    1.8904e+04
#              crBin9_In    1.3400e+04
#                lumi_In    0.0000e+00
#   n_exp_binacc_proc_background    1.0000e+00
#   n_exp_binrej_proc_background    1.0000e+00
#                      r    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 crBin1    0.0000e+00    5.5270e-02 +/-  9.64e-01  <none>
#                crBin10    0.0000e+00   -2.5737e-01 +/-  9.59e-01  <none>
#                crBin11    0.0000e+00    6.1227e-02 +/-  9.73e-01  <none>
#                crBin12    0.0000e+00   -3.5033e-01 +/-  9.87e-01  <none>
#                crBin13    0.0000e+00    5.6788e-01 +/-  9.62e-01  <none>
#                crBin14    0.0000e+00   -3.0683e-01 +/-  9.71e-01  <none>
#                crBin15    0.0000e+00   -1.6296e-01 +/-  9.58e-01  <none>
#                crBin16    0.0000e+00    4.4109e-01 +/-  9.69e-01  <none>
#                crBin17    0.0000e+00   -2.0875e-01 +/-  9.61e-01  <none>
#                crBin18    0.0000e+00   -2.6625e-01 +/-  9.78e-01  <none>
#                crBin19    0.0000e+00    4.9733e-01 +/-  9.77e-01  <none>
#                 crBin2    0.0000e+00   -1.2968e-01 +/-  9.81e-01  <none>
#                crBin20    0.0000e+00   -4.2112e-01 +/-  9.89e-01  <none>
#                crBin21    0.0000e+00   -1.0804e-01 +/-  9.91e-01  <none>
#                crBin22    0.0000e+00   -4.0704e-01 +/-  1.00e+00  <none>
#                crBin23    0.0000e+00    2.3510e-02 +/-  9.94e-01  <none>
#                crBin24    0.0000e+00    6.6097e-01 +/-  9.79e-01  <none>
#                crBin25    0.0000e+00   -4.8494e-02 +/-  9.85e-01  <none>
#                crBin26    0.0000e+00    3.1021e-01 +/-  9.75e-01  <none>
#                crBin27    0.0000e+00   -1.0660e-01 +/-  1.02e+00  <none>
#                crBin28    0.0000e+00   -2.7781e-01 +/-  1.03e+00  <none>
#                crBin29    0.0000e+00    6.6983e-02 +/-  1.02e+00  <none>
#                 crBin3    0.0000e+00   -4.3928e-01 +/-  9.73e-01  <none>
#                crBin30    0.0000e+00   -1.3077e-01 +/-  1.01e+00  <none>
#                crBin31    0.0000e+00   -3.1673e-01 +/-  1.04e+00  <none>
#                crBin32    0.0000e+00    1.7489e-01 +/-  1.02e+00  <none>
#                crBin33    0.0000e+00    9.3207e-01 +/-  9.61e-01  <none>
#                crBin34    0.0000e+00    7.4303e-02 +/-  1.04e+00  <none>
#                crBin35    0.0000e+00    6.6824e-01 +/-  1.01e+00  <none>
#                crBin36    0.0000e+00   -1.3646e-01 +/-  1.09e+00  <none>
#                crBin37    0.0000e+00   -1.5791e-01 +/-  1.08e+00  <none>
#                 crBin4    0.0000e+00    1.3066e+00 +/-  9.69e-01  <none>
#                 crBin5    0.0000e+00   -5.2918e-02 +/-  9.57e-01  <none>
#                 crBin6    0.0000e+00   -6.8288e-01 +/-  9.75e-01  <none>
#                 crBin7    0.0000e+00    5.4995e-02 +/-  9.75e-01  <none>
#                 crBin8    0.0000e+00   -2.3339e-01 +/-  9.65e-01  <none>
#                 crBin9    0.0000e+00   -1.5921e-02 +/-  9.66e-01  <none>
#                    eff    1.0067e-01    1.0067e-01 +/-  3.39e-04  <none>
#                   lumi    0.0000e+00    0.0000e+00 +/-  9.94e-01  <none>
#
#
#   RooFitResult: minimized FCN value: -3.2454, estimated distance to minimum: 9.63468e-06
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#             crBin10_In    9.7420e+03
#             crBin11_In    6.8980e+03
#             crBin12_In    5.0880e+03
#             crBin13_In    3.7160e+03
#             crBin14_In    2.8180e+03
#             crBin15_In    2.0260e+03
#             crBin16_In    1.4940e+03
#             crBin17_In    1.1590e+03
#             crBin18_In    9.7300e+02
#             crBin19_In    7.2900e+02
#              crBin1_In    3.3807e+05
#             crBin20_In    5.8500e+02
#             crBin21_In    4.7200e+02
#             crBin22_In    3.3700e+02
#             crBin23_In    2.7400e+02
#             crBin24_In    1.9000e+02
#             crBin25_In    2.0600e+02
#             crBin26_In    1.1400e+02
#             crBin27_In    1.1100e+02
#             crBin28_In    8.6000e+01
#             crBin29_In    6.4000e+01
#              crBin2_In    2.0890e+05
#             crBin30_In    6.0000e+01
#             crBin31_In    5.3000e+01
#             crBin32_In    3.0000e+01
#             crBin33_In    2.2000e+01
#             crBin34_In    2.6000e+01
#             crBin35_In    1.9000e+01
#             crBin36_In    1.5000e+01
#             crBin37_In    1.6000e+01
#              crBin3_In    1.3303e+05
#              crBin4_In    8.6258e+04
#              crBin5_In    5.8089e+04
#              crBin6_In    3.9126e+04
#              crBin7_In    2.7029e+04
#              crBin8_In    1.8904e+04
#              crBin9_In    1.3400e+04
#                lumi_In    0.0000e+00
#   n_exp_binacc_proc_background    1.0000e+00
#   n_exp_binrej_proc_background    1.0000e+00
#                      r    0.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 crBin1    0.0000e+00    5.5270e-02 +/-  9.64e-01  <none>
#                crBin10    0.0000e+00   -2.5737e-01 +/-  9.59e-01  <none>
#                crBin11    0.0000e+00    6.1227e-02 +/-  9.73e-01  <none>
#                crBin12    0.0000e+00   -3.5033e-01 +/-  9.87e-01  <none>
#                crBin13    0.0000e+00    5.6788e-01 +/-  9.62e-01  <none>
#                crBin14    0.0000e+00   -3.0683e-01 +/-  9.71e-01  <none>
#                crBin15    0.0000e+00   -1.6296e-01 +/-  9.58e-01  <none>
#                crBin16    0.0000e+00    4.4109e-01 +/-  9.69e-01  <none>
#                crBin17    0.0000e+00   -2.0875e-01 +/-  9.61e-01  <none>
#                crBin18    0.0000e+00   -2.6625e-01 +/-  9.78e-01  <none>
#                crBin19    0.0000e+00    4.9733e-01 +/-  9.77e-01  <none>
#                 crBin2    0.0000e+00   -1.2968e-01 +/-  9.81e-01  <none>
#                crBin20    0.0000e+00   -4.2112e-01 +/-  9.89e-01  <none>
#                crBin21    0.0000e+00   -1.0804e-01 +/-  9.91e-01  <none>
#                crBin22    0.0000e+00   -4.0704e-01 +/-  1.00e+00  <none>
#                crBin23    0.0000e+00    2.3510e-02 +/-  9.94e-01  <none>
#                crBin24    0.0000e+00    6.6097e-01 +/-  9.79e-01  <none>
#                crBin25    0.0000e+00   -4.8494e-02 +/-  9.85e-01  <none>
#                crBin26    0.0000e+00    3.1021e-01 +/-  9.75e-01  <none>
#                crBin27    0.0000e+00   -1.0660e-01 +/-  1.02e+00  <none>
#                crBin28    0.0000e+00   -2.7781e-01 +/-  1.03e+00  <none>
#                crBin29    0.0000e+00    6.6983e-02 +/-  1.02e+00  <none>
#                 crBin3    0.0000e+00   -4.3928e-01 +/-  9.73e-01  <none>
#                crBin30    0.0000e+00   -1.3077e-01 +/-  1.01e+00  <none>
#                crBin31    0.0000e+00   -3.1673e-01 +/-  1.04e+00  <none>
#                crBin32    0.0000e+00    1.7489e-01 +/-  1.02e+00  <none>
#                crBin33    0.0000e+00    9.3207e-01 +/-  9.61e-01  <none>
#                crBin34    0.0000e+00    7.4303e-02 +/-  1.04e+00  <none>
#                crBin35    0.0000e+00    6.6824e-01 +/-  1.01e+00  <none>
#                crBin36    0.0000e+00   -1.3646e-01 +/-  1.09e+00  <none>
#                crBin37    0.0000e+00   -1.5791e-01 +/-  1.08e+00  <none>
#                 crBin4    0.0000e+00    1.3066e+00 +/-  9.69e-01  <none>
#                 crBin5    0.0000e+00   -5.2918e-02 +/-  9.57e-01  <none>
#                 crBin6    0.0000e+00   -6.8288e-01 +/-  9.75e-01  <none>
#                 crBin7    0.0000e+00    5.4995e-02 +/-  9.75e-01  <none>
#                 crBin8    0.0000e+00   -2.3339e-01 +/-  9.65e-01  <none>
#                 crBin9    0.0000e+00   -1.5921e-02 +/-  9.66e-01  <none>
#                    eff    1.0067e-01    1.0067e-01 +/-  3.39e-04  <none>
#                   lumi    0.0000e+00    0.0000e+00 +/-  9.94e-01  <none>
#
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binrej,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x6384980
#   Clients:
#     (0x6382980,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x6387b30,V-) RooAddPdf::pdf_binrej_nuis__model_bonly_ ""
#     (0x5fa49f0,V-) RooProdPdf::pdfbins_binrej ""
#     (0x5e80350,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)                       lumi_Pdf
#       2)  pdf_binrej_nuis__model_bonly_
#       3)                 pdfbins_binrej
# --- RooAbsReal ---
#
#   Plot label is "pdf_binrej__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore rej (rej)
#   Contains 37 entries
#   Observables:
#     1)       x = 4850  L(1200 - 4900) B(37)  "x"
#     2)  weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in rej_x, pdf pdf_binrej__model_bonly_ = 960139
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [ORIGNAME:pdf_binacc,SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x63e7e80
#   Clients:
#     (0x6382980,V-) RooSimultaneousOpt::_model_bonly_ "model_s"
#   Servers:
#     (0x63e9da0,V-) RooAddPdf::pdf_binacc_nuis__model_bonly_ ""
#     (0x6027170,V-) RooProdPdf::pdfbins_binacc ""
#     (0x5e80350,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)                       lumi_Pdf
#       2)  pdf_binacc_nuis__model_bonly_
#       3)                 pdfbins_binacc
# --- RooAbsReal ---
#
#   Plot label is "pdf_binacc__model_bonly_"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore acc (acc)
#   Contains 37 entries
#   Observables:
#     1)       x = 4850  L(1200 - 4900) B(37)  "x"
#     2)  weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in acc_x, pdf pdf_binacc__model_bonly_ = 96659.9
# Error in <TList::Clear>: A list is accessing an object (0x60736ac) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x6073954) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./rej_x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./rej_x_fit_b_logy.png has been created
# Info in <TCanvas::Print>: png file ./acc_x_fit_b.png has been created
# Info in <TCanvas::Print>: png file ./acc_x_fit_b_logy.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_b.png has been created
#
#   RooFitResult: minimized FCN value: -3.40112, estimated distance to minimum: 2.39696e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#             crBin10_In    9.7420e+03
#             crBin11_In    6.8980e+03
#             crBin12_In    5.0880e+03
#             crBin13_In    3.7160e+03
#             crBin14_In    2.8180e+03
#             crBin15_In    2.0260e+03
#             crBin16_In    1.4940e+03
#             crBin17_In    1.1590e+03
#             crBin18_In    9.7300e+02
#             crBin19_In    7.2900e+02
#              crBin1_In    3.3807e+05
#             crBin20_In    5.8500e+02
#             crBin21_In    4.7200e+02
#             crBin22_In    3.3700e+02
#             crBin23_In    2.7400e+02
#             crBin24_In    1.9000e+02
#             crBin25_In    2.0600e+02
#             crBin26_In    1.1400e+02
#             crBin27_In    1.1100e+02
#             crBin28_In    8.6000e+01
#             crBin29_In    6.4000e+01
#              crBin2_In    2.0890e+05
#             crBin30_In    6.0000e+01
#             crBin31_In    5.3000e+01
#             crBin32_In    3.0000e+01
#             crBin33_In    2.2000e+01
#             crBin34_In    2.6000e+01
#             crBin35_In    1.9000e+01
#             crBin36_In    1.5000e+01
#             crBin37_In    1.6000e+01
#              crBin3_In    1.3303e+05
#              crBin4_In    8.6258e+04
#              crBin5_In    5.8089e+04
#              crBin6_In    3.9126e+04
#              crBin7_In    2.7029e+04
#              crBin8_In    1.8904e+04
#              crBin9_In    1.3400e+04
#                lumi_In    0.0000e+00
#   n_exp_binacc_proc_background    1.0000e+00
#   n_exp_binrej_proc_background    1.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue +/-  Error     GblCorr.
#   --------------------  ------------  --------------------------  --------
#                 crBin1    0.0000e+00    5.9373e-02 +/-  9.70e-01  <none>
#                crBin10    0.0000e+00   -2.5798e-01 +/-  9.53e-01  <none>
#                crBin11    0.0000e+00    5.9114e-02 +/-  9.72e-01  <none>
#                crBin12    0.0000e+00   -3.5296e-01 +/-  9.56e-01  <none>
#                crBin13    0.0000e+00    5.6178e-01 +/-  9.64e-01  <none>
#                crBin14    0.0000e+00   -3.1265e-01 +/-  9.58e-01  <none>
#                crBin15    0.0000e+00   -1.7176e-01 +/-  9.59e-01  <none>
#                crBin16    0.0000e+00    4.2766e-01 +/-  9.60e-01  <none>
#                crBin17    0.0000e+00   -2.2426e-01 +/-  9.65e-01  <none>
#                crBin18    0.0000e+00   -2.8465e-01 +/-  9.75e-01  <none>
#                crBin19    0.0000e+00    4.6898e-01 +/-  9.61e-01  <none>
#                 crBin2    0.0000e+00   -1.2616e-01 +/-  9.58e-01  <none>
#                crBin20    0.0000e+00   -4.5128e-01 +/-  9.82e-01  <none>
#                crBin21    0.0000e+00   -1.4899e-01 +/-  9.94e-01  <none>
#                crBin22    0.0000e+00   -4.5955e-01 +/-  1.02e+00  <none>
#                crBin23    0.0000e+00   -4.9170e-02 +/-  1.02e+00  <none>
#                crBin24    0.0000e+00    5.7381e-01 +/-  1.02e+00  <none>
#                crBin25    0.0000e+00   -7.6724e-02 +/-  9.88e-01  <none>
#                crBin26    0.0000e+00    2.9697e-01 +/-  9.73e-01  <none>
#                crBin27    0.0000e+00   -1.1110e-01 +/-  1.00e+00  <none>
#                crBin28    0.0000e+00   -2.8075e-01 +/-  1.01e+00  <none>
#                crBin29    0.0000e+00    6.4069e-02 +/-  1.01e+00  <none>
#                 crBin3    0.0000e+00   -4.3593e-01 +/-  9.57e-01  <none>
#                crBin30    0.0000e+00   -1.3300e-01 +/-  1.01e+00  <none>
#                crBin31    0.0000e+00   -3.1869e-01 +/-  1.04e+00  <none>
#                crBin32    0.0000e+00    1.7229e-01 +/-  1.01e+00  <none>
#                crBin33    0.0000e+00    9.3112e-01 +/-  9.52e-01  <none>
#                crBin34    0.0000e+00    7.2941e-02 +/-  1.05e+00  <none>
#                crBin35    0.0000e+00    6.6542e-01 +/-  9.90e-01  <none>
#                crBin36    0.0000e+00   -1.3731e-01 +/-  1.09e+00  <none>
#                crBin37    0.0000e+00   -1.5869e-01 +/-  1.08e+00  <none>
#                 crBin4    0.0000e+00    1.3062e+00 +/-  9.52e-01  <none>
#                 crBin5    0.0000e+00   -5.1298e-02 +/-  9.57e-01  <none>
#                 crBin6    0.0000e+00   -6.8076e-01 +/-  9.56e-01  <none>
#                 crBin7    0.0000e+00    5.5528e-02 +/-  9.56e-01  <none>
#                 crBin8    0.0000e+00   -2.3282e-01 +/-  9.61e-01  <none>
#                 crBin9    0.0000e+00   -1.6289e-02 +/-  9.53e-01  <none>
#                    eff    1.0067e-01    1.0067e-01 +/-  3.42e-04  <none>
#                   lumi    0.0000e+00   -1.1497e-05 +/-  9.94e-01  <none>
#                      r    1.0000e+00    3.1899e-01 +/-  1.14e+00  <none>
#
# Running Minos for POI
# Run Minos in  Real time 0:00:00, CP time 0.070
#
#
#   RooFitResult: minimized FCN value: -3.40112, estimated distance to minimum: 2.39696e-05
#                 covariance matrix quality: Full, accurate covariance matrix
#                 Status : MINIMIZE=0 HESSE=0
#
#     Constant Parameter    Value
#   --------------------  ------------
#             crBin10_In    9.7420e+03
#             crBin11_In    6.8980e+03
#             crBin12_In    5.0880e+03
#             crBin13_In    3.7160e+03
#             crBin14_In    2.8180e+03
#             crBin15_In    2.0260e+03
#             crBin16_In    1.4940e+03
#             crBin17_In    1.1590e+03
#             crBin18_In    9.7300e+02
#             crBin19_In    7.2900e+02
#              crBin1_In    3.3807e+05
#             crBin20_In    5.8500e+02
#             crBin21_In    4.7200e+02
#             crBin22_In    3.3700e+02
#             crBin23_In    2.7400e+02
#             crBin24_In    1.9000e+02
#             crBin25_In    2.0600e+02
#             crBin26_In    1.1400e+02
#             crBin27_In    1.1100e+02
#             crBin28_In    8.6000e+01
#             crBin29_In    6.4000e+01
#              crBin2_In    2.0890e+05
#             crBin30_In    6.0000e+01
#             crBin31_In    5.3000e+01
#             crBin32_In    3.0000e+01
#             crBin33_In    2.2000e+01
#             crBin34_In    2.6000e+01
#             crBin35_In    1.9000e+01
#             crBin36_In    1.5000e+01
#             crBin37_In    1.6000e+01
#              crBin3_In    1.3303e+05
#              crBin4_In    8.6258e+04
#              crBin5_In    5.8089e+04
#              crBin6_In    3.9126e+04
#              crBin7_In    2.7029e+04
#              crBin8_In    1.8904e+04
#              crBin9_In    1.3400e+04
#                lumi_In    0.0000e+00
#   n_exp_binacc_proc_background    1.0000e+00
#   n_exp_binrej_proc_background    1.0000e+00
#
#     Floating Parameter  InitialValue    FinalValue (+HiError,-LoError)    GblCorr.
#   --------------------  ------------  ----------------------------------  --------
#                 crBin1    0.0000e+00    5.9373e-02         +/-  9.70e-01  <none>
#                crBin10    0.0000e+00   -2.5798e-01         +/-  9.53e-01  <none>
#                crBin11    0.0000e+00    5.9114e-02         +/-  9.72e-01  <none>
#                crBin12    0.0000e+00   -3.5296e-01         +/-  9.56e-01  <none>
#                crBin13    0.0000e+00    5.6178e-01         +/-  9.64e-01  <none>
#                crBin14    0.0000e+00   -3.1265e-01         +/-  9.58e-01  <none>
#                crBin15    0.0000e+00   -1.7176e-01         +/-  9.59e-01  <none>
#                crBin16    0.0000e+00    4.2766e-01         +/-  9.60e-01  <none>
#                crBin17    0.0000e+00   -2.2426e-01         +/-  9.65e-01  <none>
#                crBin18    0.0000e+00   -2.8465e-01         +/-  9.75e-01  <none>
#                crBin19    0.0000e+00    4.6898e-01         +/-  9.61e-01  <none>
#                 crBin2    0.0000e+00   -1.2616e-01         +/-  9.58e-01  <none>
#                crBin20    0.0000e+00   -4.5128e-01         +/-  9.82e-01  <none>
#                crBin21    0.0000e+00   -1.4899e-01         +/-  9.94e-01  <none>
#                crBin22    0.0000e+00   -4.5955e-01         +/-  1.02e+00  <none>
#                crBin23    0.0000e+00   -4.9170e-02         +/-  1.02e+00  <none>
#                crBin24    0.0000e+00    5.7381e-01         +/-  1.02e+00  <none>
#                crBin25    0.0000e+00   -7.6724e-02         +/-  9.88e-01  <none>
#                crBin26    0.0000e+00    2.9697e-01         +/-  9.73e-01  <none>
#                crBin27    0.0000e+00   -1.1110e-01         +/-  1.00e+00  <none>
#                crBin28    0.0000e+00   -2.8075e-01         +/-  1.01e+00  <none>
#                crBin29    0.0000e+00    6.4069e-02         +/-  1.01e+00  <none>
#                 crBin3    0.0000e+00   -4.3593e-01         +/-  9.57e-01  <none>
#                crBin30    0.0000e+00   -1.3300e-01         +/-  1.01e+00  <none>
#                crBin31    0.0000e+00   -3.1869e-01         +/-  1.04e+00  <none>
#                crBin32    0.0000e+00    1.7229e-01         +/-  1.01e+00  <none>
#                crBin33    0.0000e+00    9.3112e-01         +/-  9.52e-01  <none>
#                crBin34    0.0000e+00    7.2941e-02         +/-  1.05e+00  <none>
#                crBin35    0.0000e+00    6.6542e-01         +/-  9.90e-01  <none>
#                crBin36    0.0000e+00   -1.3731e-01         +/-  1.09e+00  <none>
#                crBin37    0.0000e+00   -1.5869e-01         +/-  1.08e+00  <none>
#                 crBin4    0.0000e+00    1.3062e+00         +/-  9.52e-01  <none>
#                 crBin5    0.0000e+00   -5.1298e-02         +/-  9.57e-01  <none>
#                 crBin6    0.0000e+00   -6.8076e-01         +/-  9.56e-01  <none>
#                 crBin7    0.0000e+00    5.5528e-02         +/-  9.56e-01  <none>
#                 crBin8    0.0000e+00   -2.3282e-01         +/-  9.61e-01  <none>
#                 crBin9    0.0000e+00   -1.6289e-02         +/-  9.53e-01  <none>
#                    eff    1.0067e-01    1.0067e-01         +/-  3.42e-04  <none>
#                   lumi    0.0000e+00   -1.1497e-05         +/-  9.94e-01  <none>
#                      r    1.0000e+00    3.1899e-01 (+1.20e+00,-3.16e-01)  <none>
#
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x5fa3a10
#   Clients:
#     (0x5fa6070,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x5e5e020,V-) RooAddPdf::pdf_binrej_nuis ""
#     (0x5fa49f0,V-) RooProdPdf::pdfbins_binrej ""
#     (0x5e80350,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         lumi_Pdf
#       2)  pdf_binrej_nuis
#       3)   pdfbins_binrej
# --- RooAbsReal ---
#
#   Plot label is "pdf_binrej"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore rej (rej)
#   Contains 37 entries
#   Observables:
#     1)       x = 4850  L(1200 - 4900) B(37)  "x"
#     2)  weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in rej_x, pdf pdf_binrej = 960142
#  PDF CHECKING
# --- RooAbsArg ---
#   Value State: DIRTY
#   Shape State: DIRTY
#   Attributes:  [SnapShot_ExtRefClone,forceGenBinned]
#   Address: 0x5fb5b30
#   Clients:
#     (0x5fa6070,V-) RooSimultaneousOpt::model_s "model_s"
#   Servers:
#     (0x5fb6ae0,V-) RooAddPdf::pdf_binacc_nuis ""
#     (0x6027170,V-) RooProdPdf::pdfbins_binacc ""
#     (0x5e80350,V-) SimpleGaussianConstraint::lumi_Pdf "lumi_Pdf"
#   Proxies:
#     !pdfs ->
#       1)         lumi_Pdf
#       2)  pdf_binacc_nuis
#       3)   pdfbins_binacc
# --- RooAbsReal ---
#
#   Plot label is "pdf_binacc"
# --- RooAbsPdf ---
# Cached value = 0
# DataStore acc (acc)
#   Contains 37 entries
#   Observables:
#     1)       x = 4850  L(1200 - 4900) B(37)  "x"
#     2)  weight = 0  L(-1e+09 - 1e+09)  "weight"
#   Dataset variable "_weight_" is interpreted as the event weight
#  ------------
# [utils::makePlots] Number of events for pdf in acc_x, pdf pdf_binacc = 96661.1
# Error in <TList::Clear>: A list is accessing an object (0x607414c) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x60743f4) already deleted (list name = TList)
# Info in <TCanvas::Print>: png file ./rej_x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./rej_x_fit_s_logy.png has been created
# Info in <TCanvas::Print>: png file ./acc_x_fit_s.png has been created
# Info in <TCanvas::Print>: png file ./acc_x_fit_s_logy.png has been created
# Info in <TCanvas::Print>: png file ./covariance_fit_s.png has been created
#
#  --- FitDiagnostics ---
# Best fit r: 0.318993  -0.318993/+1.20073  (68% CL)
# Done in 0.36 min (cpu), 0.37 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 13
# Messages of type DEBUG : 2
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: getNormalizations) FitDiagnostics.cc: 783 -- Generating toy data for evaluating per-bin uncertainties and covariances with post-fit nuisance parameters with 200 toys
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 306 -- Fit B-only, status = 0, numBadNLL = 0, covariance quality = 3
# INFO: (function: getNormalizations) FitDiagnostics.cc: 783 -- Generating toy data for evaluating per-bin uncertainties and covariances with post-fit nuisance parameters with 200 toys
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: doFit) FitterAlgoBase.cc: 318 -- Running Minos for POI r
# DEBUG: (function: runSpecific) FitDiagnostics.cc: 416 -- Fit S+B, status = 0, numBadNLL = 0, covariance quality = 3
# INFO: (function: getNormalizations) FitDiagnostics.cc: 783 -- Generating toy data for evaluating per-bin uncertainties and covariances with post-fit nuisance parameters with 200 toys
#
# Will use saturated models to compute goodness of fit for a binned likelihood
# >>> method used is GoodnessOfFit
# >>> random number generator seed is 123456
# COMBINE_OUTPUT_FILE: higgsCombinedatacard_ws_100GeV_Ratio_inj0fb_q1percent.GoodnessOfFit.mH120.root
# Creating pdfs for individual modes (2): .    .   done.
# Object crBin1Func is duplicated
# Object crBin2Func is duplicated
# Object crBin3Func is duplicated
# Object crBin4Func is duplicated
# Object crBin5Func is duplicated
# Object crBin6Func is duplicated
# Object crBin7Func is duplicated
# Object crBin8Func is duplicated
# Object crBin9Func is duplicated
# Object crBin10Func is duplicated
# Object crBin11Func is duplicated
# Object crBin12Func is duplicated
# Object crBin13Func is duplicated
# Object crBin14Func is duplicated
# Object crBin15Func is duplicated
# Object crBin16Func is duplicated
# Object crBin17Func is duplicated
# Object crBin18Func is duplicated
# Object crBin19Func is duplicated
# Object crBin20Func is duplicated
# Object crBin21Func is duplicated
# Object crBin22Func is duplicated
# Object crBin23Func is duplicated
# Object crBin24Func is duplicated
# Object crBin25Func is duplicated
# Object crBin26Func is duplicated
# Object crBin27Func is duplicated
# Object crBin28Func is duplicated
# Object crBin29Func is duplicated
# Object crBin30Func is duplicated
# Object crBin31Func is duplicated
# Object crBin32Func is duplicated
# Object crBin33Func is duplicated
# Object crBin34Func is duplicated
# Object crBin35Func is duplicated
# Object crBin36Func is duplicated
# Object crBin37Func is duplicated
# Object bin1Func is duplicated
# Object bin2Func is duplicated
# Object bin3Func is duplicated
# Object bin4Func is duplicated
# Object bin5Func is duplicated
# Object bin6Func is duplicated
# Object bin7Func is duplicated
# Object bin8Func is duplicated
# Object bin9Func is duplicated
# Object bin10Func is duplicated
# Object bin11Func is duplicated
# Object bin12Func is duplicated
# Object bin13Func is duplicated
# Object bin14Func is duplicated
# Object bin15Func is duplicated
# Object bin16Func is duplicated
# Object bin17Func is duplicated
# Object bin18Func is duplicated
# Object bin19Func is duplicated
# Object bin20Func is duplicated
# Object bin21Func is duplicated
# Object bin22Func is duplicated
# Object bin23Func is duplicated
# Object bin24Func is duplicated
# Object bin25Func is duplicated
# Object bin26Func is duplicated
# Object bin27Func is duplicated
# Object bin28Func is duplicated
# Object bin29Func is duplicated
# Object bin30Func is duplicated
# Object bin31Func is duplicated
# Object bin32Func is duplicated
# Object bin33Func is duplicated
# Object bin34Func is duplicated
# Object bin35Func is duplicated
# Object bin36Func is duplicated
# Object bin37Func is duplicated
# Importing combined pdf model_s
# Importing combined pdf model_b
# Generating saturated model for rej
#  bin                 x    weight
#    0              1250  338072.0000000
#    1              1350  208905.0000000
#    2              1450  133033.0000000
#    3              1550  86258.0000000
#    4              1650  58089.0000000
#    5              1750  39126.0000000
#    6              1850  27029.0000000
#    7              1950  18904.0000000
#    8              2050  13400.0000000
#    9              2150  9742.0000000
#   10              2250  6898.0000000
#   11              2350  5088.0000000
#   12              2450  3716.0000000
#   13              2550  2818.0000000
#   14              2650  2026.0000000
#   15              2750  1494.0000000
#   16              2850  1159.0000000
#   17              2950   973.0000000
#   18              3050   729.0000000
#   19              3150   585.0000000
#   20              3250   472.0000000
#   21              3350   337.0000000
#   22              3450   274.0000000
#   23              3550   190.0000000
#   24              3650   206.0000000
#   25              3750   114.0000000
#   26              3850   111.0000000
#   27              3950    86.0000000
#   28              4050    64.0000000
#   29              4150    60.0000000
#   30              4250    53.0000000
#   31              4350    30.0000000
#   32              4450    22.0000000
#   33              4550    26.0000000
#   34              4650    19.0000000
#   35              4750    15.0000000
#   36              4850    16.0000000
# Generating saturated model for acc
#  bin                 x    weight
#    0              1250  34070.0000000
#    1              1350  20966.0000000
#    2              1450  13217.0000000
#    3              1550  9106.0000000
#    4              1650  5834.0000000
#    5              1750  3791.0000000
#    6              1850  2731.0000000
#    7              1950  1868.0000000
#    8              2050  1347.0000000
#    9              2150   953.0000000
#   10              2250   700.0000000
#   11              2350   485.0000000
#   12              2450   412.0000000
#   13              2550   266.0000000
#   14              2650   196.0000000
#   15              2750   169.0000000
#   16              2850   109.0000000
#   17              2950    89.0000000
#   18              3050    88.0000000
#   19              3150    48.0000000
#   20              3250    45.0000000
#   21              3350    26.0000000
#   22              3450    28.0000000
#   23              3550    29.0000000
#   24              3650    20.0000000
#   25              3750    15.0000000
#   26              3850    10.0000000
#   27              3950     6.0000000
#   28              4050     7.0000000
#   29              4150     5.0000000
#   30              4250     3.0000000
#   31              4350     4.0000000
#   32              4450     7.0000000
#   33              4550     3.0000000
#   34              4650     5.0000000
#   35              4750     1.0000000
#   36              4850     1.0000000
# RooSimultaneousOpt: number of channel masks must equal number of channels
#  --- GoodnessOfFit ---
# Best fit test statistic: 59.3793
# Done in 0.00 min (cpu), 0.00 min (real)
# Printing Message Summary From ... combine_logger.out
# ----------------------------------------------
# Messages of type INFO : 6
# Messages of type DEBUG : 0
# Messages of type ERROR : 0
# ----------------------------------------------
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 167 -- Minimisation configured with Type=Minuit2, Algo=Migrad, strategy=1, tolerance=0.1
# INFO: (function: improveOnce) CascadeMinimizer.cc: 190 -- Minimisation finished with status=0
# INFO: (function: improveOnce) CascadeMinimizer.cc: 195 -- Minimization success! status=0

# %%
# Loop over all quantiles, datasetts and do GF with toys and on real dataset
from subprocess import Popen
import shlex 
for i,qkey in enumerate(quants):
    for sig_inj in sig_inj_vals:
        skey = int(0)
        quantile = int(qkey*100)
        prefix = 'inj{}fb_q{}percent'.format(skey,quantile)
        # get obseverved goodness of fit test statistic (signal strength = 0)
        get_ipython().system('combine -M GoodnessOfFit --algo saturated --expectSignal 0 --fixedSignalStrength 0 -d {WNAME}_ratio_{P}.txt -n {WNAME}_Ratio_{P} --dataset data_obs'.format(P=prefix, WNAME=wsfile))

        processes = []
        # get expected goodness of fit test statistic distribution from frequentist toys
        for i in range(1):
            command = 'combine -M GoodnessOfFit --algo saturated --expectSignal 0 --fixedSignalStrength 0 -d {WNAME}_ratio_{P}.txt -t 200 --toysFreq -n {WNAME}_Ratio_{P}  --dataset data_obs -s {SEED}'.format(P=prefix,SEED=40+i, WNAME=wsfile)
            processes.append(Popen(shlex.split(command)))
            #get_ipython().system('combine -M GoodnessOfFit --algo saturated --fixedSignalStrength 0 -d datacard_ratio.txt -t 100 --toysFreq -n Ratio_inj%i  --dataset data_obs_inj%i -s %i'%(sig_inj,sig_inj,40+i))
        for p in processes:
            p.wait()
        get_ipython().system('hadd -f higgsCombine{WNAME}_Ratio_{P}.GoodnessOfFit.mH120.123456.root higgsCombine{WNAME}_Ratio_{P}.GoodnessOfFit.mH120.4*.root'.format(P=prefix,WNAME=wsfile))
        break
    break
# Out:
#  <<< Combine >>>
# Will use saturated models to compute goodness of fit for a binned likelihood
# >>> method used is GoodnessOfFit
# >>> random number generator seed is 123456
# COMBINE_OUTPUT_FILE: higgsCombinedatacard_ws_100GeV_Ratio_inj0fb_q1percent.GoodnessOfFit.mH120.root
# Object crBin1Func is duplicated
# Object crBin2Func is duplicated
# Object crBin3Func is duplicated
# Object crBin4Func is duplicated
# Object crBin5Func is duplicated
# Object crBin6Func is duplicated
# Object crBin7Func is duplicated
# Object crBin8Func is duplicated
# Object crBin9Func is duplicated
# Object crBin10Func is duplicated
# Object crBin11Func is duplicated
# Object crBin12Func is duplicated
# Object crBin13Func is duplicated
# Object crBin14Func is duplicated
# Object crBin15Func is duplicated
# Object crBin16Func is duplicated
# Object crBin17Func is duplicated
# Object crBin18Func is duplicated
# Object crBin19Func is duplicated
# Object crBin20Func is duplicated
# Object crBin21Func is duplicated
# Object crBin22Func is duplicated
# Object crBin23Func is duplicated
# Object crBin24Func is duplicated
# Object crBin25Func is duplicated
# Object crBin26Func is duplicated
# Object crBin27Func is duplicated
# Object crBin28Func is duplicated
# Object crBin29Func is duplicated
# Object crBin30Func is duplicated
# Object crBin31Func is duplicated
# Object crBin32Func is duplicated
# Object crBin33Func is duplicated
# Object crBin34Func is duplicated
# Object crBin35Func is duplicated
# Object crBin36Func is duplicated
# Object crBin37Func is duplicated
# Object bin1Func is duplicated
# Object bin2Func is duplicated
# Object bin3Func is duplicated
# Object bin4Func is duplicated
# Object bin5Func is duplicated
# Object bin6Func is duplicated
# Object bin7Func is duplicated
# Object bin8Func is duplicated
# Object bin9Func is duplicated
# Object bin10Func is duplicated
# Object bin11Func is duplicated
# Object bin12Func is duplicated
# Object bin13Func is duplicated
# Object bin14Func is duplicated
# Object bin15Func is duplicated
# Object bin16Func is duplicated
# Object bin17Func is duplicated
# Object bin18Func is duplicated
# Object bin19Func is duplicated
# Object bin20Func is duplicated
# Object bin21Func is duplicated
# Object bin22Func is duplicated
# Object bin23Func is duplicated
# Object bin24Func is duplicated
# Object bin25Func is duplicated
# Object bin26Func is duplicated
# Object bin27Func is duplicated
# Object bin28Func is duplicated
# Object bin29Func is duplicated
# Object bin30Func is duplicated
# Object bin31Func is duplicated
# Object bin32Func is duplicated
# Object bin33Func is duplicated
# Object bin34Func is duplicated
# Object bin35Func is duplicated
# Object bin36Func is duplicated
# Object bin37Func is duplicated
# RooSimultaneousOpt: number of channel masks must equal number of channels
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 59.3793
# Done in 0.00 min (cpu), 0.00 min (real)
# hadd Target file: higgsCombinedatacard_ws_100GeV_Ratio_inj0fb_q1percent.GoodnessOfFit.mH120.123456.root
# hadd compression setting for all ouput: 1
# hadd Source file 1: higgsCombinedatacard_ws_100GeV_Ratio_inj0fb_q1percent.GoodnessOfFit.mH120.40.root
# hadd Target path: higgsCombinedatacard_ws_100GeV_Ratio_inj0fb_q1percent.GoodnessOfFit.mH120.123456.root:/
# hadd Target path: higgsCombinedatacard_ws_100GeV_Ratio_inj0fb_q1percent.GoodnessOfFit.mH120.123456.root:/toys
#  <<< Combine >>>
# Will use saturated models to compute goodness of fit for a binned likelihood
# >>> method used is GoodnessOfFit
# >>> random number generator seed is 40
# COMBINE_OUTPUT_FILE: higgsCombinedatacard_ws_100GeV_Ratio_inj0fb_q1percent.GoodnessOfFit.mH120.40.root
# Object crBin1Func is duplicated
# Object crBin2Func is duplicated
# Object crBin3Func is duplicated
# Object crBin4Func is duplicated
# Object crBin5Func is duplicated
# Object crBin6Func is duplicated
# Object crBin7Func is duplicated
# Object crBin8Func is duplicated
# Object crBin9Func is duplicated
# Object crBin10Func is duplicated
# Object crBin11Func is duplicated
# Object crBin12Func is duplicated
# Object crBin13Func is duplicated
# Object crBin14Func is duplicated
# Object crBin15Func is duplicated
# Object crBin16Func is duplicated
# Object crBin17Func is duplicated
# Object crBin18Func is duplicated
# Object crBin19Func is duplicated
# Object crBin20Func is duplicated
# Object crBin21Func is duplicated
# Object crBin22Func is duplicated
# Object crBin23Func is duplicated
# Object crBin24Func is duplicated
# Object crBin25Func is duplicated
# Object crBin26Func is duplicated
# Object crBin27Func is duplicated
# Object crBin28Func is duplicated
# Object crBin29Func is duplicated
# Object crBin30Func is duplicated
# Object crBin31Func is duplicated
# Object crBin32Func is duplicated
# Object crBin33Func is duplicated
# Object crBin34Func is duplicated
# Object crBin35Func is duplicated
# Object crBin36Func is duplicated
# Object crBin37Func is duplicated
# Object bin1Func is duplicated
# Object bin2Func is duplicated
# Object bin3Func is duplicated
# Object bin4Func is duplicated
# Object bin5Func is duplicated
# Object bin6Func is duplicated
# Object bin7Func is duplicated
# Object bin8Func is duplicated
# Object bin9Func is duplicated
# Object bin10Func is duplicated
# Object bin11Func is duplicated
# Object bin12Func is duplicated
# Object bin13Func is duplicated
# Object bin14Func is duplicated
# Object bin15Func is duplicated
# Object bin16Func is duplicated
# Object bin17Func is duplicated
# Object bin18Func is duplicated
# Object bin19Func is duplicated
# Object bin20Func is duplicated
# Object bin21Func is duplicated
# Object bin22Func is duplicated
# Object bin23Func is duplicated
# Object bin24Func is duplicated
# Object bin25Func is duplicated
# Object bin26Func is duplicated
# Object bin27Func is duplicated
# Object bin28Func is duplicated
# Object bin29Func is duplicated
# Object bin30Func is duplicated
# Object bin31Func is duplicated
# Object bin32Func is duplicated
# Object bin33Func is duplicated
# Object bin34Func is duplicated
# Object bin35Func is duplicated
# Object bin36Func is duplicated
# Object bin37Func is duplicated
# Generate toy 1/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 49.5834
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 2/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 56.1033
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 3/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.2282
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 4/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 30.5057
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 5/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 43.4662
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 6/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.9237
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 7/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 28.3286
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 8/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 30.2179
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 9/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.8928
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 10/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.2409
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 11/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 30.8671
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 12/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.9629
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 13/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 26.2325
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 14/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 38.2814
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 15/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.0449
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 16/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 35.9437
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 17/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 33.6697
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 18/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.0265
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 19/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 37.0384
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 20/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 28.5391
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 21/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 51.353
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 22/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.637
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 23/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 29.1746
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 24/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 51.5806
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 25/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 29.2649
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 26/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.2024
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 27/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 45.7427
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 28/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 47.0911
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 29/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 29.7958
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 30/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 41.0748
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 31/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 37.9132
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 32/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.026
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 33/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 26.8899
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 34/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 24.6162
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 35/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 56.1208
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 36/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.5981
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 37/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 63.2721
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 38/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 41.0921
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 39/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 45.5618
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 40/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 46.1835
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 41/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.2892
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 42/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.9331
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 43/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 48.2494
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 44/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.3465
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 45/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.2723
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 46/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 41.3413
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 47/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.4998
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 48/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 49.0922
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 49/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.8852
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 50/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.2991
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 51/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 42.7927
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 52/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 65.6845
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 53/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 55.5971
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 54/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 38.2557
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 55/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.6131
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 56/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 43.3836
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 57/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.712
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 58/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 29.3599
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 59/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 30.3524
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 60/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 42.8213
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 61/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 37.9237
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 62/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.1996
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 63/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 43.5613
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 64/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 41.2909
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 65/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.1014
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 66/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 29.4692
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 67/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 44.3389
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 68/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 29.6417
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 69/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.2971
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 70/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 29.1595
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 71/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 22.4734
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 72/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 43.3542
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 73/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 30.167
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 74/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 40.3403
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 75/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.2718
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 76/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 40.4311
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 77/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 56.1152
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 78/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 48.4224
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 79/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 50.2481
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 80/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.6386
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 81/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 27.7345
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 82/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 40.3185
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 83/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 33.9329
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 84/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 28.2529
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 85/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 43.1525
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 86/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.6232
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 87/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 28.3058
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 88/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 55.1646
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 89/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 54.2941
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 90/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 33.0333
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 91/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.3521
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 92/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 38.8892
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 93/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 25.9135
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 94/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 22.1792
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 95/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.5007
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 96/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 35.6826
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 97/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.2734
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 98/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 44.274
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 99/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.2034
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 100/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 35.8032
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 101/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 21.1847
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 102/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 37.2185
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 103/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.4976
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 104/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 38.2482
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 105/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.0437
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 106/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 23.0586
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 107/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 29.3479
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 108/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 37.5518
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 109/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 37.9913
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 110/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 51.582
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 111/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.9914
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 112/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.7783
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 113/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 33.9599
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 114/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 57.0246
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 115/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.5675
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 116/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 22.8755
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 117/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 27.6535
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 118/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 37.7689
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 119/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.2192
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 120/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 38.7425
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 121/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 33.5239
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 122/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 41.5852
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 123/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 30.1859
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 124/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 43.1483
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 125/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 19.4519
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 126/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 44.2394
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 127/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 38.9575
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 128/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.8289
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 129/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.8538
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 130/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 23.5833
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 131/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 53.2629
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 132/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 33.0294
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 133/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 26.0803
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 134/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 23.0925
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 135/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.8361
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 136/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 30.8606
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 137/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 38.51
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 138/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 42.6932
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 139/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 40.973
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 140/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.5109
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 141/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.9556
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 142/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.8732
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 143/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 44.1707
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 144/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 44.2153
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 145/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 43.2536
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 146/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 27.376
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 147/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 30.6126
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 148/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 30.6152
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 149/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.359
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 150/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 35.9351
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 151/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.9425
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 152/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.7624
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 153/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 28.7491
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 154/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 25.7032
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 155/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 50.5023
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 156/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 45.3486
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 157/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 22.1577
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 158/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.6668
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 159/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 33.3437
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 160/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.7797
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 161/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 46.241
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 162/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 26.6273
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 163/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 47.2549
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 164/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 20.7722
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 165/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 24.4559
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 166/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.4201
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 167/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 33.8322
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 168/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 47.1008
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 169/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 44.7699
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 170/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 41.718
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 171/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 37.9166
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 172/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.5588
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 173/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.5939
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 174/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 29.3745
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 175/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.2376
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 176/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.0256
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 177/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 31.8781
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 178/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 27.4975
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 179/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.572
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 180/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 46.1735
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 181/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 44.3344
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 182/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 24.7879
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 183/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 38.6698
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 184/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.1147
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 185/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 50.4576
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 186/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 43.0471
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 187/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 28.8873
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 188/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 26.8966
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 189/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 32.2824
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 190/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 25.1051
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 191/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 44.4237
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 192/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.396
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 193/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 36.949
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 194/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 42.5008
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 195/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 39.5633
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 196/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 28.8629
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 197/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 29.4068
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 198/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 34.4816
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 199/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 35.3437
# Done in 0.00 min (cpu), 0.00 min (real)
# Generate toy 200/200
#
#  --- GoodnessOfFit ---
# Best fit test statistic: 26.0645
# Done in 0.00 min (cpu), 0.00 min (real)
# mean   expected limit: r < 36.6941 +/- 0.59701 @ 95%CL (200 toyMC)
# median expected limit: r < 36.0732 @ 95%CL (200 toyMC)
#    68% expected band : 28.8873 < r < 44.3389
#    95% expected band : 22.4734 < r < 56.1152
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels
# RooSimultaneousOpt: number of channel masks must equal number of channels

# %%
# Plot GOF
for i,qkey in enumerate(quants):
    if i>0:
        break
    if i > 0:
        lower_bound = quants[i-1]
    else:
        lower_bound = 0.0 
#     for sig_inj in sig_inj_vals:
    skey = int(0)
    quantile = int(qkey*100)
    prefix = 'inj{}fb_q{}percent'.format(skey,quantile)
    
    efficiency = qkey
    # open file
    obs_gof_file = uproot.open('higgsCombine{WNAME}_Ratio_{P}.GoodnessOfFit.mH120.root'.format(P=prefix,WNAME=wsfile))
    obs_gof = obs_gof_file['limit'].arrays('limit')['limit'][0]

    exp_gof_file = uproot.open('higgsCombine{WNAME}_Ratio_{P}.GoodnessOfFit.mH120.123456.root'.format(P=prefix,WNAME=wsfile))
    exp_gof = exp_gof_file['limit'].arrays('limit')['limit']
    
    # get p-value from toys
    n_extreme = len(exp_gof[exp_gof > obs_gof])
    n_total = len(exp_gof)
    pval_toys = 1.*n_extreme/n_total
    
    # get p-value assuming chi2 dist (may not be valid)
    pval = rt.TMath.Prob(obs_gof,n_bins)
    print('sig inj = %.1f fb, gof = %.2f, p-value (from chi2) = %.6f, p-value (from toys) = %.6f'%(sig_inj*sig_xsec,obs_gof,pval,pval_toys))
    
    bin_width = (max(exp_gof+[obs_gof])+np.std(exp_gof)-(min(exp_gof)-np.std(exp_gof)))/30.
    exp_gof_hist = rt.TH1D('gof','gof',30,min(exp_gof)-np.std(exp_gof), max(exp_gof+[obs_gof])+np.std(exp_gof))
    exp_gof_hist_gt = rt.TH1D('gof_gt','gof_gt',30,min(exp_gof)-np.std(exp_gof), max(exp_gof+[obs_gof])+np.std(exp_gof))
    for g in exp_gof: 
        exp_gof_hist.Fill(g)
        if g > obs_gof: 
            exp_gof_hist_gt.Fill(g)
        
        
    d = rt.TCanvas("ratio", "", 1000, 800)
    d.SetLeftMargin(0.13)
    # signal_hist_template    .Draw('same HIST')
    
    rt.gStyle.SetOptTitle(0)
    rt.gStyle.SetOptStat(0)
    f = rt.TF1("chi2","%f*ROOT::Math::chisquared_pdf(x,%i,0)"%(exp_gof_hist.Integral()*bin_width,n_bins),min(exp_gof)-np.std(exp_gof),max(exp_gof+[obs_gof])+np.std(exp_gof))

    tleg = rt.TLegend(0.48, 0.6, 0.89, 0.85)
    tleg.SetTextSize(0.05)
    tleg.SetBorderSize(0)
    tleg.SetFillStyle(0)
    tleg.SetTextSize (0.03)
    tleg.SetTextFont( 62 )
    tleg.SetTextSize (0.03)
    tleg.SetTextFont( 42 )
    exp_gof_hist.Draw('hist')
    exp_gof_hist.SetXTitle('Test statistic -2ln#lambda')
    exp_gof_hist.SetYTitle('N toys')
    exp_gof_hist.SetTitle("")
    exp_gof_hist.GetYaxis().SetLabelSize(0.05)
    exp_gof_hist.GetYaxis().SetTitleSize(0.05)
    f.SetLineColor((rt.TColor.GetColor(scol[1])))
    exp_gof_hist.SetLineWidth(2)
    exp_gof_hist.SetLineColor((rt.TColor.GetColor(bcol[0])))
    exp_gof_hist_gt.SetLineColor((rt.TColor.GetColor(bcol[0])))
    exp_gof_hist_gt.SetFillColorAlpha((rt.TColor.GetColor(bcol[0])), 0.30)
    exp_gof_hist_gt.Draw('fhistsame')
    f.Draw('same')
    line = rt.TLine(obs_gof,0,obs_gof,exp_gof_hist.GetMaximum())
    line.SetLineWidth(2)
    line.Draw()
    tleg.AddEntry(exp_gof_hist_gt,'p-value (from toys) = %.2f'%pval_toys)
    tleg.AddEntry(f,'p-value (from #chi^{2}) = %.2f'%pval,'l')
    tleg.AddEntry(line,'Observed (Best fit = {:.1f})'.format(obs_gof),'l')
    tleg.Draw()
    latex = rt.TLatex()
    latex.SetNDC ()
    latex.SetTextSize (0.03)
    latex.SetTextFont( 62 )
    latex.DrawLatex (0.67 ,0.27 , "%.1f fb^{-1} dijet events"%lumi)
    latex.SetTextSize (0.03)
    latex.SetTextFont( 42 )
    latex.DrawLatex(0.67 ,0.23 , 'q = {} - {}'.format(lower_bound,qkey))
    latex.DrawLatex(0.67 ,0.19 , "Acc./rej. = {:.2f}".format(efficiency))
    latex.DrawLatex(0.67 ,0.15 , "100 GeV binning")
    d.Draw()
    d.SaveAs('gof_{}_100GeVbinning.pdf'.format(prefix))
# Out:
# sig inj = 0.0 fb, gof = 59.38, p-value (from chi2) = 0.011223, p-value (from toys) = 0.010000
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ratio
# Info in <TCanvas::Print>: pdf file gof_inj0fb_q1percent_100GeVbinning.pdf has been created

# %%
# by hand GOF calculation
fitDiag = rt.TFile.Open('fitDiagnostics_fit_result.root','r')

byhand_gof = 0

f = rt.TCanvas('f','f',1000,800)
f.cd()
for cat in ['rej', 'acc']:
    bkgd = fitDiag.Get('shapes_fit_b/{cat}/background'.format(cat=cat))
    bkgd.Scale(100) # need to multiply by bin width for some reason?
    data = fitDiag.Get('shapes_fit_b/{cat}/data'.format(cat=cat))
    if cat=='rej': 
        bkgd.Draw('hist')
        bkgd.SetMinimum(5000)
        bkgd.SetMaximum(15000)
        bkgd.GetXaxis().SetRangeUser(1400,1700)
    else:
        bkgd.Draw("histsame")
    data.SetMarkerStyle(20)
    data.SetMarkerColor(rt.kBlack)
    for i in range(0,bkgd.GetNbinsX()):
        data.SetPointEXlow(i,0)
        data.SetPointEXhigh(i,0)
        data.SetPoint(i,data.GetX()[i], 100*data.GetY()[i]) # need to multiply by bin width for some reason?
        data.SetPointEYlow(i,100*data.GetErrorYlow(i)) # need to multiply by bin width for some reason?
        data.SetPointEYhigh(i,100*data.GetErrorYhigh(i)) # need to multiply by bin width for some reason?
    data.Draw('samepez') 
    

    for i in range(0,bkgd.GetNbinsX()):
        fi = bkgd.GetBinContent(i+1)
        di = data.GetY()[i]
        gofi = 2*(fi - di + di*rt.TMath.Log(di/fi)) # see eq. 14 of http://cousins.web.cern.ch/cousins/ongoodness6march2016.pdf
        
        # expect each bin to give GOF contribution ~ O(1)
        if gofi>5: 
            print('{cat} bin {i}: fi={fi}, di={di}, gofi={gofi}'.format(cat=cat,i=i,fi=fi,di=di,gofi=gofi))
            print(" -> BIG GOF CONTRIBUTION in this bin")
        byhand_gof += gofi


print("by hand GOF = {}".format(byhand_gof))
print("combine GOF = {}".format(obs_gof))

#f.SetLogy()
f.Draw()
#fitDiag.Close()
# Out:
# acc bin 3: fi=8722.48535156, di=9106.0, gofi=16.6207194033
#  -> BIG GOF CONTRIBUTION in this bin
# by hand GOF = 59.3793313412
# combine GOF = 59.3793013766
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: f

# %%
# # set up workspace, combined
# acc_bin_functions_all = {}
# rej_bin_functions_all = {}
# for i,key in enumerate(sorted(histos_data.keys())):
#     prefix = 'q'+str(int(key*100))
#     print('Working on quantile {}'.format(prefix))
    
#     datacard_ws = rt.TFile.Open('datacard_ws_{}.root'.format(prefix),'recreate')
#     w = rt.RooWorkspace('w','w')
#     # Set up mjj in dijet invariant mass range and import
#     x = rt.RooRealVar('x','x',min_bin,max_bin)
#     w.factory('x[%.1f,%.1f]'%(min_bin, max_bin))

#     # Set up the correct efficiency which should yield data_observed = efficiency*background_template
#     w.factory('eff_%s[%f,0,1]'%(prefix,histos_data[key].Integral()/background_hist_template.Integral()))
#     w.var('eff_{}'.format(prefix)).setConstant(True)
#     print('eff_{}'.format(prefix))
#     print(histos_data[key].Integral()/background_hist_template.Integral())
#     #Loop over all bins and set 
#     # - background template per bin as crBin_func = (mjj_in+mjj_in/sqrt(mjj_in))^crBin
#     # - accepted template based on quantile used as bin = eff * crBin+func
#     acc_bin_functions = rt.RooArgList()
#     rej_bin_functions = rt.RooArgList()
#     empty_hist = rt.TH1D('empty_hist','empty_hist', n_bins, min_bin, max_bin)
#     for iBinX in range(1,n_bins+1):
#         empty_hist.SetBinContent(iBinX,1)
#         w.factory('crBin%i_In[%.1f]'%(iBinX,background_hist_template.GetBinContent(iBinX)))
#         w.factory('crBin%i[0,-100,100]'%(iBinX))
#         w.var('crBin%i_In'%iBinX).setConstant(True)
#         w.var('crBin%i'%iBinX).setConstant(False)
#         if background_hist_template.GetBinContent(iBinX) == 0:
#             w.factory("expr::crBin%iFunc('max(0,@0)',crBin%i_In)"%(iBinX,iBinX))
#         else:    
#             w.factory("expr::crBin%iFunc('max(0,@0*pow(1.0+%f,@1))',crBin%i_In,crBin%i)"%(iBinX,1/rt.TMath.Sqrt(background_hist_template.GetBinContent(iBinX)),iBinX,iBinX))
#         w.factory("expr::bin%iFunc_%s('max(0,@0*@1)',eff_%s,crBin%iFunc)"%(iBinX,prefix,prefix,iBinX))
#         rej_bin_functions.add(w.function('crBin%iFunc'%iBinX))
#         acc_bin_functions.add(w.function('bin%iFunc_%s'%(iBinX,prefix)))
#     acc_bin_functions_all[key] = acc_bin_functions
#     rej_bin_functions_all[key] = rej_bin_functions
    
#     #Create the parametric histograms from the functions defined above
#     qcd_rph_rej = rt.RooParametricHist('background_rej','background_rej',w.var('x'),rej_bin_functions,empty_hist)
#     qcd_rph_rej_norm = rt.RooAddition('background_rej_norm','background_rej_norm',rej_bin_functions)
#     qcd_rph_acc = rt.RooParametricHist('background_acc_{}'.format(prefix),'background_acc_{}'.format(prefix),w.var('x'),acc_bin_functions,empty_hist)
#     qcd_rph_acc_norm = rt.RooAddition('background_acc_norm_{}'.format(prefix),'background_acc_norm_{}'.format(prefix),acc_bin_functions)

#     #Import all
#     getattr(w,'import')(qcd_rph_rej, rt.RooCmdArg())
#     getattr(w,'import')(qcd_rph_rej_norm, rt.RooFit.RecycleConflictNodes())
#     getattr(w,'import')(qcd_rph_acc, rt.RooCmdArg())
#     getattr(w,'import')(qcd_rph_acc_norm, rt.RooFit.RecycleConflictNodes())
    
#     ds_signal_acc = rt.RooDataHist('signal_acc_{}'.format(prefix),'signal_acc_{}'.format(prefix),rt.RooArgList(w.var('x')),histos_signal[key])
#     ds_signal_rej = rt.RooDataHist('signal_rej','signal_rej',rt.RooArgList(w.var('x')),signal_hist_template)
#     getattr(w,'import')(ds_signal_acc, rt.RooCmdArg())
#     getattr(w,'import')(ds_signal_rej, rt.RooCmdArg())
    
#     # Import data, no injected signal (baseline) and with injected signal
#     ds_data_acc = {}
#     ds_data_rej = {}
#     data_acc = rt.RooDataHist('data_obs_acc_%s'%(prefix),'data_obs_acc_%s'%(prefix),rt.RooArgList(w.var('x')),histos_data[key])
#     data_rej = rt.RooDataHist('data_obs_rej','data_obs_rej',rt.RooArgList(w.var('x')),background_hist_template)

#     getattr(w,'import')(data_acc, rt.RooCmdArg())
#     getattr(w,'import')(data_rej, rt.RooCmdArg())
        
#     for sig_inj in sig_inj_vals:
#         print (sig_inj)
#         print (data_hist_acc_inj_all[key][sig_inj].GetName())
#         print (data_hist_acc_inj_all[key][sig_inj].Integral())

#         ds_data_acc[sig_inj] = rt.RooDataHist('data_obs_inj%i_acc_%s'%(sig_inj,prefix),'data_obs_inj%i_acc_%s'%(sig_inj,prefix),rt.RooArgList(w.var('x')),data_hist_acc_inj_all[key][sig_inj])
#         ds_data_rej[sig_inj] = rt.RooDataHist('data_obs_inj%i_rej'%(sig_inj),'data_obs_inj%i_rej'%sig_inj,rt.RooArgList(w.var('x')),data_hist_rej_inj_all[key][sig_inj])

#         getattr(w,'import')(ds_data_acc[sig_inj], rt.RooCmdArg())
#         getattr(w,'import')(ds_data_rej[sig_inj], rt.RooCmdArg())
    
#     datacard_ws.cd()
#     w.Write()
#     datacard_ws.Close()

# %%
# # set up workspace
# # Assume there is signal present both in rejected and accepted  (before: just background shape with no signal)
# for sig_inj in sig_inj_vals:
#     print (sig_inj)
#     for i,key in enumerate(sorted(histos_data.keys())):
#         if key == 1:
#             continue
        
#         prefix = 'q'+str(int(key*100))
#         print('Working on quantile {}'.format(prefix))
        
#         background_template = data_hist_rej_inj_all[key][sig_inj]
#         data                = data_hist_acc_inj_all[key][sig_inj]
        
#         #Set up workspace
#         datacard_ws = rt.TFile.Open('datacard_ws_{}_inj{}.root'.format(prefix,sig_inj),'recreate')
#         w = rt.RooWorkspace('w','w')
#         # Set up mjj in dijet invariant mass range and import
#         x = rt.RooRealVar('x','x',min_bin,max_bin)
#         w.factory('x[%.1f,%.1f]'%(min_bin, max_bin))
        
#         #Importing data with injected signal = {sig_inj}
#         print ('Using data set = {}'.format(data.GetName()))
#         print ('Yield = {}'.format(data.Integral()))
        
        
#         ds_signal_acc = rt.RooDataHist('signal_acc_{}'.format(prefix),'signal_acc_{}'.format(prefix),rt.RooArgList(w.var('x')),histos_signal[key])
#         ds_signal_rej = rt.RooDataHist('signal_rej_{}'.format(prefix),'signal_rej_{}'.format(prefix),rt.RooArgList(w.var('x')),signal_hist_template)
#         getattr(w,'import')(ds_signal_acc, rt.RooCmdArg())
#         getattr(w,'import')(ds_signal_rej, rt.RooCmdArg())

#         # Import data
#         ds_data_acc = {}
#         ds_data_rej = {}
#         data_acc = rt.RooDataHist('data_obs_acc_%s'%(prefix),'data_obs_acc_%s'%(prefix),rt.RooArgList(w.var('x')),data)
#         data_rej = rt.RooDataHist('data_obs_rej_%s'%(prefix),'data_obs_rej',rt.RooArgList(w.var('x')),background_template)
#         getattr(w,'import')(data_acc, rt.RooCmdArg())
#         getattr(w,'import')(data_rej, rt.RooCmdArg())
        
            
#         # Set up the correct efficiency which should yield data_observed = efficiency*background_template
        
#         print('Setting efficiency as : eff_{}'.format(prefix))
#         print('Setting efficiency value : eff_{}'.format(data.Integral()/background_template.Integral()))

#         w.factory('eff_%s[%f,0,1]'%(prefix,data.Integral()/background_template.Integral()))
#         w.var('eff_{}'.format(prefix)).setConstant(True)
    

#         #Loop over all bins and set 
#         # - background template per bin as crBin_func = (mjj_in+mjj_in/sqrt(mjj_in))^crBin
#         # - accepted template based on quantile used as bin = eff * crBin+func
#         acc_bin_functions = rt.RooArgList()
#         rej_bin_functions = rt.RooArgList()
#         empty_hist = rt.TH1D('empty_hist','empty_hist', n_bins, min_bin, max_bin)
#         for iBinX in range(1,n_bins+1):
#             empty_hist.SetBinContent(iBinX,1)
#             w.factory('crBin%i_In[%.1f]'%(iBinX,background_template.GetBinContent(iBinX)))
#             w.factory('crBin%i[0,-100,100]'%(iBinX))
#             w.var('crBin%i_In'%iBinX).setConstant(True)
#             w.var('crBin%i'%iBinX).setConstant(False)
#             if background_hist_template.GetBinContent(iBinX) == 0:
#                 print('Bin content is zero! Setting crBin{}Func to zero in fit.'.format(iBinX))
#                 w.factory("expr::crBin%iFunc(0)")
#             else:    
#                 w.factory("expr::crBin%iFunc('max(0,@0*pow(1.0+%f,@1))',crBin%i_In,crBin%i)"%(iBinX,1/rt.TMath.Sqrt(background_template.GetBinContent(iBinX)),iBinX,iBinX))
#             w.factory("expr::bin%iFunc_%s('max(0,@0*@1)',eff_%s,crBin%iFunc)"%(iBinX,prefix,prefix,iBinX))
#             rej_bin_functions.add(w.function('crBin%iFunc'%iBinX))
#             acc_bin_functions.add(w.function('bin%iFunc_%s'%(iBinX,prefix)))
#         acc_bin_functions_all[key] = acc_bin_functions
#         rej_bin_functions_all[key] = rej_bin_functions

#         #Create the parametric histograms from the functions defined above
#         qcd_rph_rej = rt.RooParametricHist('background_rej_{}'.format(prefix),'background_rej',w.var('x'),rej_bin_functions,empty_hist)
#         qcd_rph_rej_norm = rt.RooAddition('background_rej_norm_{}'.format(prefix),'background_rej_norm',rej_bin_functions)
#         qcd_rph_acc = rt.RooParametricHist('background_acc_{}'.format(prefix),'background_acc_{}'.format(prefix),w.var('x'),acc_bin_functions,empty_hist)
#         qcd_rph_acc_norm = rt.RooAddition('background_acc_norm_{}'.format(prefix),'background_acc_norm_{}'.format(prefix),acc_bin_functions)

#         #Import all
#         getattr(w,'import')(qcd_rph_rej, rt.RooCmdArg())
#         getattr(w,'import')(qcd_rph_rej_norm, rt.RooFit.RecycleConflictNodes())
#         getattr(w,'import')(qcd_rph_acc, rt.RooCmdArg())
#         getattr(w,'import')(qcd_rph_acc_norm, rt.RooFit.RecycleConflictNodes())

#         datacard_ws.cd()
#         w.Write()
#         datacard_ws.Close()

# %%
# # datacard template
# # no background normalization uncertainty
# combine_strings = {}
# for sig_inj in sig_inj_vals:
#     print (sig_inj)
    
#     combine_string = u'combineCards.py '.format(sig_inj)
#     for i,key in enumerate(sorted(histos_data.keys())):
#         if key == 1.0:
#             continue
#         prefix = 'q'+str(int(key*100))

#         datacard_ratio = \
#         '''
#         imax 1
#         jmax 1
#         kmax *
#         ---------------
#         shapes * * {WORKSPACE} w:$PROCESS_$CHANNEL w:$PROCESS_$CHANNEL_$SYSTEMATIC
#         ---------------
#         bin {BIN}
#         observation {OBS}
#         ------------------------------
#         bin             {BIN}      {BIN}
#         process         signal     background
#         process         0          1
#         rate            {SIGRATE}    {BKGRATE}
#         --------------------------------
#         lumi lnN 1.01 -
#         eff_{PREFIX}   flatParam
#         '''

#         for i in range(1,n_bins+1):
#             datacard_ratio += 'crBin%i   flatParam\n'%i

#         datacard_ws = 'datacard_ws_{}_inj{}.root'.format(prefix,sig_inj)

#         # write datacard
#         datacard_ratio_acc = datacard_ratio.format(BIN='acc_{}'.format(prefix),
#                                   OBS=-1,
#                                   BKGRATE=1,
#                                   SIGRATE=histos_signal[key].Integral(),
#                                   WORKSPACE=datacard_ws,
#                                   PREFIX=prefix)
#         print(datacard_ratio_acc)
#         with open('datacard_ratio_acc_{}_inj{}.txt'.format(prefix,sig_inj),'w') as f:
#             f.write(datacard_ratio_acc)
#         combine_string += 'acc_{}=datacard_ratio_acc_{}_inj{}.txt '.format(prefix,prefix,sig_inj)

#         datacard_ratio_rej = datacard_ratio.format(BIN='rej_{}'.format(prefix),
#                                                OBS=-1,
#                                                BKGRATE=1,
#                                                SIGRATE=signal_hist_template.Integral(),
#                                                WORKSPACE=datacard_ws,
#                                                PREFIX=prefix) 
#         print(datacard_ratio_rej)
#         with open('datacard_ratio_rej_{}_inj{}.txt'.format(prefix,sig_inj),'w') as f:
#                 f.write(datacard_ratio_rej)
#         combine_string += 'rej_{}=datacard_ratio_rej_{}_inj{}.txt '.format(prefix,prefix,sig_inj)
        
#     combine_string += ' > datacard_ratio_inj{}.txt'.format(sig_inj)  
#     combine_strings[sig_inj] = combine_string
    
# for key in combine_strings.keys():
#     print (combine_strings[key])
#     print('\n')

# %%
# for key in combine_strings.keys():
#     print (combine_strings[key])
#     print('\n')
#     get_ipython().system(combine_strings[key])
#     get_ipython().system(u'text2workspace.py datacard_ratio_inj{}.txt'.format(key))

# %%
# get_ipython().system(u'combineCards.py rej=datacard_ratio_rej_inj0.0.txt acc_q1=datacard_ratio_acc_q1_inj0.0.txt > datacard_test_inj0_q1.txt')
# get_ipython().system(u'text2workspace.py datacard_test_inj0_q1.txt')

# %%
# get_ipython().system('combine -M GoodnessOfFit --algo saturated --fixedSignalStrength 0 -d datacard_test.root -n Ratio_inj0 --dataset data_obs_inj0 -v 2')

# %%
# sig_inj_vals = [0.,0.1,1.,2.,5.,10.]
# for sig_inj in sig_inj_vals:
#     # get obseverved goodness of fit test statistic (signal strength = 0)
#     get_ipython().system('combine -M GoodnessOfFit --algo saturated --fixedSignalStrength 0 -d datacard_ratio.txt -n Ratio_inj%i --dataset data_obs_inj%i'%(sig_inj,sig_inj))

#     processes = []
#     # get expected goodness of fit test statistic distribution from frequentist toys
#     for i in range(10):
#         command = 'combine -M GoodnessOfFit --algo saturated --fixedSignalStrength 0 -d datacard_ratio.txt -t 200 --toysFreq -n Ratio_inj%i  --dataset data_obs_inj%i -s %i'%(sig_inj,sig_inj,40+i)
#         processes.append(Popen(shlex.split(command)))
#         #get_ipython().system('combine -M GoodnessOfFit --algo saturated --fixedSignalStrength 0 -d datacard_ratio.txt -t 100 --toysFreq -n Ratio_inj%i  --dataset data_obs_inj%i -s %i'%(sig_inj,sig_inj,40+i))
#     for p in processes:
#         p.wait()
#     get_ipython().system('hadd -f higgsCombineRatio_inj%i.GoodnessOfFit.mH120.123456.root higgsCombineRatio_inj%i.GoodnessOfFit.mH120.4*.root'%(sig_inj,sig_inj))

# %%
# obs_gof_file = uproot.open('higgsCombineTest.GoodnessOfFit.mH120.root')
# obs_gof = obs_gof_file['limit'].arrays('limit')['limit'][0]
